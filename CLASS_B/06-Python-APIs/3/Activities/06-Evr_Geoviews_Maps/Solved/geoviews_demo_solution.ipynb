# %% [markdown]
# # GeoViews Maps Demo

# %% [markdown]
# ## Import Libraries

# %%
# Import the required libraries
import hvplot.pandas
import pandas as pd

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ## Define Sample Data

# %%
# Create a dictionary containing coordinates
coordinates = {
    "latitude": [-31.9523, -33.8688, -27.4705],
    "longitude": [115.8613, 151.2093, 153.0260],
    "City": ["Perth", "Sydney", "Brisbane"],
    "Population": [2099530, 4637436, 2495825]
}

# %%
# Create a Pandas DataFrame containing coordinates
coordinates_df = pd.DataFrame(coordinates)

# Display sample data
coordinates_df
# Out:
#    latitude  longitude      City  Population
# 0  -31.9523   115.8613     Perth     2099530
# 1  -33.8688   151.2093    Sydney     4637436
# 2  -27.4705   153.0260  Brisbane     2495825

# %% [markdown]
# ## Simple Map

# %%
#!pip install geoviews

# %%
# Configure the map plot_1
map_plot_1 = coordinates_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM"
)

# Display the map plot_1
map_plot_1
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\tempfile.py:256, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     255 try:
# --> 256     fd = _os.open(file, flags, 0o600)
#     257 except FileExistsError:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\ProgramData\\anaconda3\\lib\\site-packages\\datashader\\__pycache__\\tmp_sz9afui'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Configure the map plot_1
# ----> 2 map_plot_1 = coordinates_df.hvplot.points(
#       3     "longitude",
#       4     "latitude",
#       5     geo = True,
#       6     tiles = "OSM"
#       7 )
#       9 # Display the map plot_1
#      10 map_plot_1
#
# File C:\ProgramData\anaconda3\lib\site-packages\hvplot\plotting\core.py:1612, in hvPlotTabular.points(self, x, y, **kwds)
#    1554 def points(self, x=None, y=None, **kwds):
#    1555     """
#    1556     A `points` plot visualizes positions in a 2D space. This is useful for example for
#    1557     geographic plots.
#    (...)
#    1610     - HoloViews: https://holoviews.org/reference/elements/bokeh/Points.html
#    1611     """
# -> 1612     return self(x, y, kind="points", **kwds)
#
# File C:\ProgramData\anaconda3\lib\site-packages\hvplot\plotting\core.py:92, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      89         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      90         return pn.panel(plot, **panel_dict)
# ---> 92 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File C:\ProgramData\anaconda3\lib\site-packages\hvplot\plotting\core.py:99, in hvPlotBase._get_converter(self, x, y, kind, **kwds)
#      97 y = y or params.pop("y", None)
#      98 kind = kind or params.pop("kind", None)
# ---> 99 return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#
# File C:\ProgramData\anaconda3\lib\site-packages\hvplot\converter.py:396, in HoloViewsConverter.__init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     394 self.dynamic = dynamic
#     395 self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 396 self.crs = self._process_crs(data, crs) if self.geo else None
#     397 self.project = project
#     398 self.coastline = coastline
#
# File C:\ProgramData\anaconda3\lib\site-packages\hvplot\converter.py:650, in HoloViewsConverter._process_crs(self, data, crs)
#     647     _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     649 try:
# --> 650     return process_crs(_crs)
#     651 except ValueError:
#     652     # only raise error if crs was specified in kwargs
#     653     if crs:
#
# File C:\ProgramData\anaconda3\lib\site-packages\hvplot\util.py:231, in process_crs(crs)
#     229 try:
#     230     import cartopy.crs as ccrs
# --> 231     import geoviews as gv # noqa
#     232     import pyproj
#     233 except ImportError:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\geoviews\__init__.py:9
#       3 from holoviews import (extension, help, opts, output, renderer, Store, # noqa (API import)
#       4                        Cycle, Palette, Overlay, Layout, NdOverlay, NdLayout,
#       5                        HoloMap, DynamicMap, GridSpace, Dimension, dim)
#       7 from holoviews import render, save # noqa (API import)
# ----> 9 from .annotators import annotate # noqa (API import)
#      10 from .element import ( # noqa (API import)
#      11     _Element, Feature, Tiles, WMTS, LineContours, FilledContours,
#      12     Text, Image, Points, Path, Polygons, Shape, Dataset, RGB,
#      13     Contours, Graph, TriMesh, Nodes, EdgePaths, QuadMesh, VectorField,
#      14     HexTiles, Labels, Rectangles, Segments, WindBarbs
#      15 )
#      16 from .util import load_tiff, from_xarray # noqa (API import)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\geoviews\annotators.py:15
#      13 from .models.custom_tools import CheckpointTool, RestoreTool, ClearTool
#      14 from .links import VertexTableLink, PointTableLink, HvRectanglesTableLink, RectanglesTableLink
# ---> 15 from .operation import project
#      16 from .streams import PolyVertexDraw, PolyVertexEdit
#      18 Annotator._tools = [CheckpointTool, RestoreTool, ClearTool]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\geoviews\operation\__init__.py:14
#      12 geo_ops = [contours, bivariate_kde]
#      13 try:
# ---> 14     from holoviews.operation.datashader import shade, stack, dynspread
#      15     from holoviews.operation.resample import ResampleOperation2D
#      16     geo_ops += [ResampleOperation2D, shade, stack, dynspread]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\holoviews\operation\datashader.py:11
#       9 import pandas as pd
#      10 import xarray as xr
# ---> 11 import datashader as ds
#      12 import datashader.reductions as rd
#      13 import datashader.transfer_functions as tf
#
# File C:\ProgramData\anaconda3\lib\site-packages\datashader\__init__.py:8
#       5 import param
#       6 __version__ = str(param.version.Version(fpath=__file__, archive_commit="$Format:%h$",reponame="datashader"))
# ----> 8 from .core import Canvas                                 # noqa (API import)
#       9 from .reductions import *                                # noqa (API import)
#      10 from .glyphs import Point                                # noqa (API import)
#
# File C:\ProgramData\anaconda3\lib\site-packages\datashader\core.py:18
#      16 from .utils import Expr # noqa (API import)
#      17 from .resampling import resample_2d, resample_2d_distributed
# ---> 18 from . import reductions as rd
#      20 try:
#      21     import cudf
#
# File C:\ProgramData\anaconda3\lib\site-packages\datashader\reductions.py:14
#      11 from numba import cuda as nb_cuda
#      13 try:
# ---> 14     from datashader.transfer_functions._cuda_utils import (
#      15         cuda_atomic_nanmin, cuda_atomic_nanmax, cuda_args)
#      16 except ImportError:
#      17     cuda_atomic_nanmin, cuda_atomic_nanmmax, cuda_args = None, None, None
#
# File C:\ProgramData\anaconda3\lib\site-packages\datashader\transfer_functions\__init__.py:16
#      13 from PIL.Image import fromarray
#      15 from datashader.colors import rgb, Sets1to3
# ---> 16 from datashader.composite import composite_op_lookup, over, validate_operator
#      17 from datashader.utils import nansum_missing, ngjit
#      19 try:
#
# File C:\ProgramData\anaconda3\lib\site-packages\datashader\composite.py:30
#      24     elif name not in array_operators:
#      25         raise ValueError('Operator %r not one of the supported array operators: %s'
#      26                         % (how, ', '.join(repr(el[:-4]) for el in array_operators)))
#      29 @nb.jit('(uint32,)', nopython=True, nogil=True, cache=True)
# ---> 30 def extract_scaled(x):
#      31     """Extract components as float64 values in [0.0, 1.0]"""
#      32     r = np.float64(( x        & 255) / 255)
#
# File C:\ProgramData\anaconda3\lib\site-packages\numba\core\decorators.py:212, in _jit.<locals>.wrapper(func)
#     208 disp = dispatcher(py_func=func, locals=locals,
#     209                   targetoptions=targetoptions,
#     210                   **dispatcher_args)
#     211 if cache:
# --> 212     disp.enable_caching()
#     213 if sigs is not None:
#     214     # Register the Dispatcher to the type inference mechanism,
#     215     # even though the decorator hasn't returned yet.
#     216     from numba.core import typeinfer
#
# File C:\ProgramData\anaconda3\lib\site-packages\numba\core\dispatcher.py:863, in Dispatcher.enable_caching(self)
#     862 def enable_caching(self):
# --> 863     self._cache = FunctionCache(self.py_func)
#
# File C:\ProgramData\anaconda3\lib\site-packages\numba\core\caching.py:601, in Cache.__init__(self, py_func)
#     599 self._name = repr(py_func)
#     600 self._py_func = py_func
# --> 601 self._impl = self._impl_class(py_func)
#     602 self._cache_path = self._impl.locator.get_cache_path()
#     603 # This may be a bit strict but avoids us maintaining a magic number
#
# File C:\ProgramData\anaconda3\lib\site-packages\numba\core\caching.py:333, in CacheImpl.__init__(self, py_func)
#     331 source_path = inspect.getfile(py_func)
#     332 for cls in self._locator_classes:
# --> 333     locator = cls.from_function(py_func, source_path)
#     334     if locator is not None:
#     335         break
#
# File C:\ProgramData\anaconda3\lib\site-packages\numba\core\caching.py:180, in _SourceFileBackedLocatorMixin.from_function(cls, py_func, py_file)
#     178 self = cls(py_func, py_file)
#     179 try:
# --> 180     self.ensure_cache_path()
#     181 except OSError:
#     182     # Cannot ensure the cache directory exists or is writable
#     183     return
#
# File C:\ProgramData\anaconda3\lib\site-packages\numba\core\caching.py:107, in _CacheLocator.ensure_cache_path(self)
#     105 os.makedirs(path, exist_ok=True)
#     106 # Ensure the directory is writable by trying to write a temporary file
# --> 107 tempfile.TemporaryFile(dir=path).close()
#
# File C:\ProgramData\anaconda3\lib\tempfile.py:559, in NamedTemporaryFile(mode, buffering, encoding, newline, suffix, prefix, dir, delete, errors)
#     557     return fd
#     558 try:
# --> 559     file = _io.open(dir, mode, buffering=buffering,
#     560                     newline=newline, encoding=encoding, errors=errors,
#     561                     opener=opener)
#     562     try:
#     563         raw = getattr(file, 'buffer', file)
#
# File C:\ProgramData\anaconda3\lib\tempfile.py:556, in NamedTemporaryFile.<locals>.opener(*args)
#     554 def opener(*args):
#     555     nonlocal name
# --> 556     fd, name = _mkstemp_inner(dir, prefix, suffix, flags, output_type)
#     557     return fd
#
# File C:\ProgramData\anaconda3\lib\tempfile.py:262, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     258     continue    # try again
#     259 except PermissionError:
#     260     # This exception is thrown when a directory with the chosen name
#     261     # already exists on windows.
# --> 262     if (_os.name == 'nt' and _os.path.isdir(dir) and
#     263         _os.access(dir, _os.W_OK)):
#     264         continue
#     265     else:
#
# File C:\ProgramData\anaconda3\lib\genericpath.py:42, in isdir(s)
#      40 """Return true if the pathname refers to an existing directory."""
#      41 try:
# ---> 42     st = os.stat(s)
#      43 except (OSError, ValueError):
#      44     return False
#
# KeyboardInterrupt:

# %% [markdown]
# ## Map with Fixed Size

# %%
# Configure the map plot_2
map_plot_2 = coordinates_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500    
)

# Display the map plot
map_plot_2

# %% [markdown]
# ## Map with Custom Point Colors and Size

# %%
# Configure the map plot_3
map_plot_3 = coordinates_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Population",
    scale = 0.01,
    color = "City"
)

# Display the map plot
map_plot_3

# %% [markdown]
# ## Map with Custom Style and Point Colors and Size

# %%
# Configure the map plot_4
map_plot_4 = coordinates_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    size = "Population",
    scale = 0.01,
    color = "City"
)

# Display the map plot
map_plot_4
