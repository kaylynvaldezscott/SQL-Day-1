# %% [markdown]
# # Geoapify Drills
#
# Create code to answer each of the following questions.
#
# > **Hint:** You will need multiple target URLs and multiple API requests.

# %%
# Dependencies
import requests
import json

# Import the API key
from config import geoapify_key

# %%
geoapify_key
# Out:
# '4a987a25d5c0407a8b6de8933da491dc'

# %% [markdown]
# ## 1. What are the geocoordinates (latitude and longitude) of Brisbane, Australia?

# %%
# Set the search parameters
target_city = "Brisbane, Australia"

params = {
    "text": target_city,
    "apiKey": geoapify_key
}

# Build URL using the geocode endpoint
base_url = "https://api.geoapify.com/v1/geocode/search"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
response
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright'},
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'city': 'Brisbane City',
#     'lon': 153.0234991,
#     'lat': -27.4689682,
#     'state_code': 'QLD',
#     'formatted': 'Brisbane City, QLD, Australia',
#     'address_line1': 'Brisbane City',
#     'address_line2': 'QLD, Australia',
#     'category': 'administrative',
#     'timezone': {'name': 'Australia/Brisbane',
#      'offset_STD': '+10:00',
#      'offset_STD_seconds': 36000,
#      'offset_DST': '+10:00',
#      'offset_DST_seconds': 36000,
#      'abbreviation_STD': 'AEST',
#      'abbreviation_DST': 'AEST'},
#     'plus_code': '5R4MG2JF+C9',
#     'result_type': 'city',
#     'rank': {'importance': 0.8694082277592821,
#      'popularity': 6.876406158741578,
#      'confidence': 1,
#      'confidence_city_level': 1,
#      'match_type': 'full_match'},
#     'place_id': '51893f2f81c0206340592eddc94c0e783bc0f00101f9016030b20000000000c00208'},
#    'geometry': {'type': 'Point', 'coordinates': [153.0234991, -27.4689682]},
#    'bbox': [152.679693, -27.660219, 153.468275, -27.022014]}],
#  'query': {'text': 'Brisbane, Australia',
#   'parsed': {'city': 'brisbane',
#    'country': 'australia',
#    'expected_type': 'city'}}}

# %%
response.keys()
# Out:
# dict_keys(['type', 'features', 'query'])

# %%
response['features'][0]['properties']['lat']
# Out:
# -27.4689682

# %%
# Extract lat/lon
lat = response["features"][0]["properties"]["lat"]
lon = response["features"][0]["properties"]["lon"]

# Print results
print(f"{target_city}: {lat}, {lon}")
# Out:
# Brisbane, Australia: -27.4689682, 153.0234991

# %% [markdown]
# ## 2. What are the geocoordinates (latitude and longitude) of The Sydney Opera House?

# %%
# update params dict
target_city = "Sydney Opera House"

params = {
    "text": target_city,
    "apiKey": geoapify_key
}

# Build URL using the geocode endpoint
base_url = "https://api.geoapify.com/v1/geocode/search"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
response
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright'},
#     'name': 'Sydney Opera House',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Council of the City of Sydney',
#     'postcode': '2000',
#     'district': 'Quay Quarter',
#     'suburb': 'Sydney',
#     'street': 'Macquarie Street',
#     'housenumber': '2',
#     'lon': 151.21512338473752,
#     'lat': -33.85719805,
#     'state_code': 'NSW',
#     'formatted': 'Sydney Opera House, 2 Macquarie Street, Sydney NSW 2000, Australia',
#     'address_line1': 'Sydney Opera House',
#     'address_line2': '2 Macquarie Street, Sydney NSW 2000, Australia',
#     'category': 'entertainment.culture.arts_centre',
#     'timezone': {'name': 'Australia/Sydney',
#      'offset_STD': '+10:00',
#      'offset_STD_seconds': 36000,
#      'offset_DST': '+11:00',
#      'offset_DST_seconds': 39600,
#      'abbreviation_STD': 'AEST',
#      'abbreviation_DST': 'AEDT'},
#     'plus_code': '4RRH46V8+42',
#     'plus_code_short': 'V8+42 Sydney, New South Wales, Australia',
#     'result_type': 'amenity',
#     'rank': {'importance': 0.8439868225769328,
#      'popularity': 6.979585085597298,
#      'confidence': 1,
#      'match_type': 'full_match'},
#     'place_id': '51aec16f4ae2e6624059f5786baab8ed40c0f00101f901c86f920000000000c002019203125379646e6579204f7065726120486f757365'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.21512338473752, -33.85719805]},
#    'bbox': [151.214428, -33.8579291, 151.2158894, -33.856305]},
#   {'type': 'Feature',
#    'properties': {'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright'},
#     'name': 'Sydney Opera House',
#     'country': 'China',
#     'country_code': 'cn',
#     'state': 'Beijing',
#     'city': 'Fengtai District',
#     'village': '郭公庄村',
#     'postcode': '100070',
#     'suburb': 'Hua‘xiang',
#     'street': '葆台路',
#     'lon': 116.2844542,
#     'lat': 39.8078321,
#     'formatted': 'Sydney Opera House, 葆台路, Hua‘xiang, 100070 Beijing, China',
#     'address_line1': 'Sydney Opera House',
#     'address_line2': '葆台路, Hua‘xiang, 100070 Beijing, China',
#     'category': 'tourism.attraction',
#     'timezone': {'name': 'Asia/Shanghai',
#      'offset_STD': '+08:00',
#      'offset_STD_seconds': 28800,
#      'offset_DST': '+08:00',
#      'offset_DST_seconds': 28800,
#      'abbreviation_STD': 'CST',
#      'abbreviation_DST': 'CST'},
#     'plus_code': '8PFRR75M+4Q',
#     'result_type': 'amenity',
#     'rank': {'importance': 0.30001,
#      'popularity': 2.6769029610356663,
#      'confidence': 1,
#      'match_type': 'full_match'},
#     'place_id': '516e8d637f34125d40595a14d10a67e74340f00103f9015173cdbd00000000c002019203125379646e6579204f7065726120486f757365'},
#    'geometry': {'type': 'Point', 'coordinates': [116.2844542, 39.8078321]},
#    'bbox': [116.2844042, 39.8077821, 116.2845042, 39.8078821]}],
#  'query': {'text': 'Sydney Opera House'}}

# %%
# Extract lat/lon
lat = response["features"][0]["properties"]["lat"]
lon = response["features"][0]["properties"]["lon"]

# Print results
print(f"{target_city}: {lat}, {lon}")
# Out:
# Sydney Opera House: -33.85719805, 151.21512338473752

# %% [markdown]
# ## 3. Find the name and address of a pharmacy in Brisbane, Australia.
#
# > **Hint:** Review <https://apidocs.geoapify.com/docs/places/#categories>.

# %%
# Set the geographical coordinates for Brisbane, Australia
latitude = -27.4705
longitude = 153.0260

# Set the parameters for the type of place
categories = "healthcare.pharmacy"

# Set the parameters for the type of search
bias = f"proximity:{longitude},{latitude}"
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    "limit":limit,
    "bias":bias,
    "apiKey":geoapify_key    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
response
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Priceline Pharmacy',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4000',
#     'city_district': 'Brisbane City',
#     'district': 'Greater Brisbane',
#     'suburb': 'Brisbane City',
#     'street': 'Queen Street',
#     'housenumber': '120',
#     'lon': 153.0248629,
#     'lat': -27.4697548,
#     'state_code': 'QLD',
#     'formatted': 'Priceline Pharmacy, 120 Queen Street, Brisbane City QLD 4000, Australia',
#     'address_line1': 'Priceline Pharmacy',
#     'address_line2': '120 Queen Street, Brisbane City QLD 4000, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Priceline Pharmacy',
#       'brand': 'Priceline Pharmacy',
#       'osm_id': 1546536181,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'healthcare': 'pharmacy',
#       'brand:wikidata': 'Q7242652',
#       'brand:wikipedia': 'en:Priceline (Australia)'}},
#     'distance': 139,
#     'place_id': '5146cc47adcb2063405939d4bcd941783bc0f00103f901f5442e5c0000000092031250726963656c696e6520506861726d616379'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.02486289999996, -27.469754799462155]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Priceline Pharmacy',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'city': 'Brisbane City',
#     'postcode': '4000',
#     'district': 'Brisbane City',
#     'suburb': 'Brisbane City',
#     'street': 'Albert Street',
#     'housenumber': '108',
#     'lon': 153.0268978,
#     'lat': -27.4715417,
#     'state_code': 'QLD',
#     'formatted': 'Priceline Pharmacy, 108 Albert Street, Brisbane City QLD 4000, Australia',
#     'address_line1': 'Priceline Pharmacy',
#     'address_line2': '108 Albert Street, Brisbane City QLD 4000, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Priceline Pharmacy',
#       'brand': 'Priceline Pharmacy',
#       'osm_id': 1541754211,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'healthcare': 'pharmacy',
#       'wheelchair': 'yes',
#       'brand:wikidata': 'Q7242652',
#       'brand:wikipedia': 'en:Priceline (Australia)',
#       'toilets:wheelchair': 'no'}},
#     'distance': 146,
#     'place_id': '51b36ac658dc20634059b1e3f1f4b6783bc0f00103f901634de55b0000000092031250726963656c696e6520506861726d616379'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.0268978, -27.47154169946197]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Wizard Pharmacy',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4000',
#     'city_district': 'Brisbane City',
#     'district': 'Greater Brisbane',
#     'suburb': 'Brisbane City',
#     'street': 'Queen Street Mall',
#     'lon': 153.024774,
#     'lat': -27.469005,
#     'state_code': 'QLD',
#     'formatted': 'Wizard Pharmacy, Queen Street Mall, Brisbane City QLD 4000, Australia',
#     'address_line1': 'Wizard Pharmacy',
#     'address_line2': 'Queen Street Mall, Brisbane City QLD 4000, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Wizard Pharmacy',
#       'osm_id': 6320207377,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'healthcare': 'pharmacy'}},
#     'distance': 205,
#     'place_id': '5151f9d7f2ca20634059cf592eb610783bc0f00103f90111b6b6780100000092030f57697a61726420506861726d616379'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.024774, -27.46900499946224]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Chemist Warehouse',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4000',
#     'city_district': 'Brisbane City',
#     'district': 'Greater Brisbane',
#     'suburb': 'Brisbane City',
#     'street': 'Queen Street',
#     'housenumber': '60',
#     'lon': 153.0238264,
#     'lat': -27.4705774,
#     'state_code': 'QLD',
#     'formatted': 'Chemist Warehouse, 60 Queen Street, Brisbane City QLD 4000, Australia',
#     'address_line1': 'Chemist Warehouse',
#     'address_line2': '60 Queen Street, Brisbane City QLD 4000, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Chemist Warehouse',
#       'brand': 'Chemist Warehouse',
#       'osm_id': 5151109719,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'healthcare': 'pharmacy',
#       'brand:wikidata': 'Q48782120',
#       'brand:wikipedia': 'en:Chemist Warehouse'}},
#     'distance': 215,
#     'place_id': '510119952fc32063405920edacc277783bc0f00103f90157b20733010000009203114368656d6973742057617265686f757365'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.0238264, -27.47057739946206]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Priceline Pharmacy',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'city': 'Brisbane City',
#     'postcode': '4000',
#     'district': 'Brisbane City',
#     'suburb': 'Brisbane City',
#     'street': 'Queen Street',
#     'housenumber': '160',
#     'lon': 153.0250366,
#     'lat': -27.4686894,
#     'state_code': 'QLD',
#     'formatted': 'Priceline Pharmacy, 160 Queen Street, Brisbane City QLD 4000, Australia',
#     'address_line1': 'Priceline Pharmacy',
#     'address_line2': '160 Queen Street, Brisbane City QLD 4000, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Priceline Pharmacy',
#       'brand': 'Priceline Pharmacy',
#       'osm_id': 4310080112,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'healthcare': 'pharmacy',
#       'opening_hours': 'Mo-Fr 07:00-16:00, 09:00-18:00; Sa 09:00-14:00',
#       'brand:wikidata': 'Q7242652',
#       'brand:wikipedia': 'en:Priceline (Australia)'}},
#     'distance': 222,
#     'place_id': '517f468e19cd2063405919ac4a07fc773bc0f00103f901709ae6000100000092031250726963656c696e6520506861726d616379'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.0250366, -27.468689399462253]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Priceline Pharmacy',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4000',
#     'city_district': 'Brisbane City',
#     'district': 'Greater Brisbane',
#     'suburb': 'Brisbane City',
#     'street': 'Edward Street',
#     'lon': 153.027627,
#     'lat': -27.4686052,
#     'state_code': 'QLD',
#     'formatted': 'Priceline Pharmacy, Edward Street, Brisbane City QLD 4000, Australia',
#     'address_line1': 'Priceline Pharmacy',
#     'address_line2': 'Edward Street, Brisbane City QLD 4000, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Priceline Pharmacy',
#       'brand': 'Priceline Pharmacy',
#       'osm_id': 8140167944,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'dispensing': 'yes',
#       'healthcare': 'pharmacy',
#       'brand:wikidata': 'Q7242652',
#       'brand:wikipedia': 'en:Priceline (Australia)'}},
#     'distance': 264,
#     'place_id': '5192af0452e2206340590a6da682f6773bc0f00103f901081b31e50100000092031250726963656c696e6520506861726d616379'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.027627, -27.468605199462253]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Chemist Warehouse',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'city': 'Brisbane City',
#     'postcode': '4000',
#     'district': 'Brisbane City',
#     'suburb': 'Brisbane City',
#     'street': 'Edward Street',
#     'lon': 153.0290075,
#     'lat': -27.4702585,
#     'state_code': 'QLD',
#     'formatted': 'Chemist Warehouse, Edward Street, Brisbane City QLD 4000, Australia',
#     'address_line1': 'Chemist Warehouse',
#     'address_line2': 'Edward Street, Brisbane City QLD 4000, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Chemist Warehouse',
#       'brand': 'Chemist Warehouse',
#       'osm_id': 8140167945,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'addr:state': 'QLD',
#       'dispensing': 'yes',
#       'healthcare': 'pharmacy',
#       'addr:suburb': 'Brisbane',
#       'brand:wikidata': 'Q48782120',
#       'brand:wikipedia': 'en:Chemist Warehouse'}},
#     'distance': 298,
#     'place_id': '51d6fa22a1ed2063405910db6bdc62783bc0f00103f901091b31e5010000009203114368656d6973742057617265686f757365'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.02900749999998, -27.47025849946209]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Post Office Square Pharmacy',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4000',
#     'city_district': 'Brisbane City',
#     'district': 'Greater Brisbane',
#     'suburb': 'Brisbane City',
#     'street': 'Queen Street',
#     'lon': 153.0275308,
#     'lat': -27.4675315,
#     'state_code': 'QLD',
#     'formatted': 'Post Office Square Pharmacy, Queen Street, Brisbane City QLD 4000, Australia',
#     'address_line1': 'Post Office Square Pharmacy',
#     'address_line2': 'Queen Street, Brisbane City QLD 4000, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Post Office Square Pharmacy',
#       'layer': -1,
#       'osm_id': 1546982742,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'healthcare': 'pharmacy',
#       'wheelchair': 'yes',
#       'toilets:wheelchair': 'no',
#       'wheelchair:description': 'Accessible via Adelaide Street entrance'}},
#     'distance': 362,
#     'place_id': '513eb44588e1206340596f0af424b0773bc0f00103f9015615355c0000000092031b506f7374204f66666963652053717561726520506861726d616379'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.02753079999997, -27.46753149946238]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Wizard Pharmacy',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4000',
#     'city_district': 'Brisbane City',
#     'district': 'Greater Brisbane',
#     'suburb': 'Brisbane City',
#     'street': 'George Street',
#     'housenumber': '336',
#     'lon': 153.0217986,
#     'lat': -27.4693514,
#     'state_code': 'QLD',
#     'formatted': 'Wizard Pharmacy, 336 George Street, Brisbane City QLD 4000, Australia',
#     'address_line1': 'Wizard Pharmacy',
#     'address_line2': '336 George Street, Brisbane City QLD 4000, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Wizard Pharmacy',
#       'osm_id': 1546700978,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'healthcare': 'pharmacy'}},
#     'distance': 434,
#     'place_id': '512843fa92b220634059a005cf6927783bc0f00103f901b2c8305c0000000092030f57697a61726420506861726d616379'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.0217986, -27.469351399462198]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Priceline Pharmacy',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'city_district': 'Spring Hill',
#     'district': 'Greater Brisbane',
#     'suburb': 'Fortitude Valley',
#     'street': 'Turbot Street',
#     'housenumber': '365',
#     'lon': 153.0305084,
#     'lat': -27.4619919,
#     'state_code': 'QLD',
#     'formatted': 'Priceline Pharmacy, 365 Turbot Street, Fortitude Valley QLD, Australia',
#     'address_line1': 'Priceline Pharmacy',
#     'address_line2': '365 Turbot Street, Fortitude Valley QLD, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Priceline Pharmacy',
#       'brand': 'Priceline Pharmacy',
#       'osm_id': 4797796121,
#       'amenity': 'pharmacy',
#       'name:en': 'Priceline Pharmacy',
#       'osm_type': 'n',
#       'healthcare': 'pharmacy',
#       'opening_hours': 'Mo-Fr 08:00-19:00; Sa 09:00-17:00; Su 10:00-16:00',
#       'brand:wikidata': 'Q7242652',
#       'brand:wikipedia': 'en:Priceline (Australia)'}},
#     'distance': 1043,
#     'place_id': '511a88c0ecf920634059d035e31945763bc0f00103f901198ff81d0100000092031250726963656c696e6520506861726d616379'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.03050839999997, -27.46199189946293]}},
#   {'type': 'Feature',
#    'properties': {'name': 'TerryWhite Chemmart',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4101',
#     'city_district': 'South Brisbane',
#     'district': 'Greater Brisbane',
#     'neighbourhood': 'South Bank',
#     'suburb': 'South Brisbane',
#     'street': 'Grey Street',
#     'lon': 153.0235655,
#     'lat': -27.4820025,
#     'state_code': 'QLD',
#     'formatted': 'TerryWhite Chemmart, Grey Street, South Brisbane QLD 4101, Australia',
#     'address_line1': 'TerryWhite Chemmart',
#     'address_line2': 'Grey Street, South Brisbane QLD 4101, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'TerryWhite Chemmart',
#       'brand': 'TerryWhite Chemmart',
#       'osm_id': 8685936422,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'dispensing': 'yes',
#       'healthcare': 'pharmacy',
#       'brand:wikidata': 'Q24089773',
#       'brand:wikipedia': 'en:Terry White Chemmart'}},
#     'distance': 1297,
#     'place_id': '510a7a6f0cc1206340595ac60b84647b3bc0f00103f90126dfb8050200000092031354657272795768697465204368656d6d617274'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.02356549999996, -27.482002499460897]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Barracks Pharmacy',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'city': 'Brisbane City',
#     'postcode': '4000',
#     'district': 'Petrie Terrace',
#     'suburb': 'Petrie Terrace',
#     'street': 'Petrie Terrace',
#     'housenumber': '61',
#     'lon': 153.0139689,
#     'lat': -27.4654189,
#     'state_code': 'QLD',
#     'formatted': 'Barracks Pharmacy, 61 Petrie Terrace, Petrie Terrace QLD 4000, Australia',
#     'address_line1': 'Barracks Pharmacy',
#     'address_line2': '61 Petrie Terrace, Petrie Terrace QLD 4000, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Barracks Pharmacy',
#       'osm_id': 5045884261,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'healthcare': 'pharmacy',
#       'wheelchair': 'yes',
#       'opening_hours': 'Mo-We,Fr 08:00-17:00, Th 08:00-19:30, Sa 08:00-14:00, Su 09:00-13:00'}},
#     'distance': 1316,
#     'place_id': '512815e86e7220634059d42168b125773bc0f00103f9016515c22c010000009203114261727261636b7320506861726d616379'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.0139689, -27.46541889946259]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Coffey',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4169',
#     'city_district': 'Kangaroo Point',
#     'district': 'Greater Brisbane',
#     'suburb': 'Kangaroo Point',
#     'street': 'Main Street',
#     'lon': 153.0355782,
#     'lat': -27.4808584,
#     'state_code': 'QLD',
#     'formatted': 'Coffey, Main Street, Kangaroo Point QLD 4169, Australia',
#     'address_line1': 'Coffey',
#     'address_line2': 'Main Street, Kangaroo Point QLD 4169, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Coffey',
#       'osm_id': 6052259527,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'healthcare': 'pharmacy',
#       'wheelchair': 'yes'}},
#     'distance': 1488,
#     'place_id': '516aaee474232163405929b13b89197b3bc0f00103f901c726be6801000000920306436f66666579'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.03557819999997, -27.48085839946103]}},
#   {'type': 'Feature',
#    'properties': {'name': 'West End Discount Drug Stores',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4101',
#     'city_district': 'South Brisbane',
#     'district': 'Greater Brisbane',
#     'suburb': 'West End',
#     'street': 'Mollison Street',
#     'lon': 153.0119862,
#     'lat': -27.4769146,
#     'state_code': 'QLD',
#     'formatted': 'West End Discount Drug Stores, Mollison Street, West End QLD 4101, Australia',
#     'address_line1': 'West End Discount Drug Stores',
#     'address_line2': 'Mollison Street, West End QLD 4101, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare.pharmacy'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'West End Discount Drug Stores',
#       'osm_id': 506174931,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'addr:postcode': 4101,
#       'opening_hours': 'Mo-Fr 08:00-20:00; Sa 08:00-17:00; Su 09:00-18:00'}},
#     'distance': 1557,
#     'place_id': '511c20e2306220634059f5ab3f13177a3bc0f00103f901d39d2b1e0000000092031d5765737420456e6420446973636f756e7420447275672053746f726573'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.01198620000002, -27.476914599461413]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Mater Pharmacy',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4101',
#     'city_district': 'South Brisbane',
#     'district': 'Greater Brisbane',
#     'suburb': 'South Brisbane',
#     'street': 'Raymond Terrace',
#     'lon': 153.0277626,
#     'lat': -27.4849502,
#     'state_code': 'QLD',
#     'formatted': 'Mater Pharmacy, Raymond Terrace, South Brisbane QLD 4101, Australia',
#     'address_line1': 'Mater Pharmacy',
#     'address_line2': 'Raymond Terrace, South Brisbane QLD 4101, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Mater Pharmacy',
#       'osm_id': 6649314305,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'dispensing': 'yes',
#       'healthcare': 'pharmacy',
#       'drive_through': 'no',
#       'opening_hours': 'Mo-Fr 08:00-18:00'}},
#     'distance': 1611,
#     'place_id': '51a961646ee32063405938df3eb2257c3bc0f00103f901017c548c0100000092030e4d6174657220506861726d616379'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.0277626, -27.4849501994606]}},
#   {'type': 'Feature',
#    'properties': {'name': 'TerryWhite Chemmart',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4101',
#     'city_district': 'West End',
#     'district': 'Greater Brisbane',
#     'neighbourhood': 'Hill End',
#     'suburb': 'West End',
#     'street': 'Boundary Street',
#     'housenumber': '97',
#     'lon': 153.0115955,
#     'lat': -27.4773983,
#     'state_code': 'QLD',
#     'formatted': 'TerryWhite Chemmart, 97 Boundary Street, West End QLD 4101, Australia',
#     'address_line1': 'TerryWhite Chemmart',
#     'address_line2': '97 Boundary Street, West End QLD 4101, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'TerryWhite Chemmart',
#       'brand': 'TerryWhite Chemmart',
#       'osm_id': 8924429400,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'healthcare': 'pharmacy',
#       'brand:wikidata': 'Q24089773',
#       'brand:wikipedia': 'en:Terry White Chemmart'}},
#     'distance': 1616,
#     'place_id': '51fca886fd5e20634059455a63c6367a3bc0f00103f90158fcef130200000092031354657272795768697465204368656d6d617274'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.0115955, -27.477398299461374]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Gladstone Road Pharmacy',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4101',
#     'city_district': 'Highgate Hill',
#     'district': 'Greater Brisbane',
#     'suburb': 'Highgate Hill',
#     'street': 'Gladstone Road',
#     'housenumber': '30-34',
#     'lon': 153.0198823,
#     'lat': -27.4845053,
#     'state_code': 'QLD',
#     'formatted': 'Gladstone Road Pharmacy, 30-34 Gladstone Road, Highgate Hill QLD 4101, Australia',
#     'address_line1': 'Gladstone Road Pharmacy',
#     'address_line2': '30-34 Gladstone Road, Highgate Hill QLD 4101, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare.pharmacy'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Gladstone Road Pharmacy',
#       'osm_id': 506174928,
#       'amenity': 'pharmacy',
#       'osm_type': 'n'}},
#     'distance': 1666,
#     'place_id': '519e8834e0a22063405912ec0f8a087c3bc0f00103f901d09d2b1e00000000920317476c616473746f6e6520526f616420506861726d616379'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.0198823, -27.484505299460643]}},
#   {'type': 'Feature',
#    'properties': {'name': 'TerryWhite Chemmart',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4101',
#     'city_district': 'West End',
#     'district': 'Greater Brisbane',
#     'neighbourhood': 'Hill End',
#     'suburb': 'West End',
#     'street': 'Boundary Street',
#     'housenumber': '154',
#     'lon': 153.0122181,
#     'lat': -27.4808789,
#     'state_code': 'QLD',
#     'formatted': 'TerryWhite Chemmart, 154 Boundary Street, West End QLD 4101, Australia',
#     'address_line1': 'TerryWhite Chemmart',
#     'address_line2': '154 Boundary Street, West End QLD 4101, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'TerryWhite Chemmart',
#       'brand': 'TerryWhite Chemmart',
#       'osm_id': 2798568500,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'healthcare': 'pharmacy',
#       'wheelchair': 'yes',
#       'opening_hours': 'Mo-Sa 08:00-19:00; Su 08:00-16:00',
#       'brand:wikidata': 'Q24089773',
#       'brand:wikipedia': 'en:Terry White Chemmart',
#       'opening_hours:covid19': 'open'}},
#     'distance': 1783,
#     'place_id': '516a7d3617642063405985852ae11a7b3bc0f00103f90134c4cea60000000092031354657272795768697465204368656d6d617274'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.01221809999998, -27.480878899461022]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Andrew Thanos Pharmacy',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4101',
#     'city_district': 'West End',
#     'district': 'Greater Brisbane',
#     'neighbourhood': 'Hill End',
#     'suburb': 'West End',
#     'street': 'Boundary Street',
#     'housenumber': '197A',
#     'lon': 153.0120306,
#     'lat': -27.4806878,
#     'state_code': 'QLD',
#     'formatted': 'Andrew Thanos Pharmacy, 197A Boundary Street, West End QLD 4101, Australia',
#     'address_line1': 'Andrew Thanos Pharmacy',
#     'address_line2': '197A Boundary Street, West End QLD 4101, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details.contact', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Andrew Thanos Pharmacy',
#       'phone': '+61738443086',
#       'osm_id': 5960364324,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'dispensing': 'yes',
#       'healthcare': 'pharmacy',
#       'wheelchair': 'yes',
#       'addr:street': 'Boundary Street',
#       'drive_through': 'no',
#       'addr:housenumber': '197A'}},
#     'distance': 1783,
#     'place_id': '51a431ff8d622063405977450a5b0e7b3bc0f00103f90124f1436301000000920316416e64726577205468616e6f7320506861726d616379'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.0120306, -27.480687799461034]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Taylor Medical Centre',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Queensland',
#     'postcode': '4102',
#     'city_district': 'Woolloongabba',
#     'district': 'Greater Brisbane',
#     'neighbourhood': 'Gabba Hill',
#     'suburb': 'Woolloongabba',
#     'street': 'Catherine Street',
#     'lon': 153.0288273,
#     'lat': -27.4879562,
#     'state_code': 'QLD',
#     'formatted': 'Taylor Medical Centre, Catherine Street, Woolloongabba QLD 4102, Australia',
#     'address_line1': 'Taylor Medical Centre',
#     'address_line2': 'Catherine Street, Woolloongabba QLD 4102, Australia',
#     'categories': ['commercial.health_and_beauty',
#      'commercial.health_and_beauty.pharmacy',
#      'healthcare',
#      'healthcare.pharmacy'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Taylor Medical Centre',
#       'osm_id': 431441647,
#       'amenity': 'pharmacy',
#       'osm_type': 'n',
#       'healthcare': 'pharmacy',
#       'addr:postcode': 4102}},
#     'distance': 1954,
#     'place_id': '516cd73a27ec20634059fc8f8eb2ea7c3bc0f00103f901ef46b719000000009203155461796c6f72204d65646963616c2043656e747265'},
#    'geometry': {'type': 'Point',
#     'coordinates': [153.0288273, -27.4879561994603]}}]}

# %%
response.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
response['features'][0]['properties']['name']
# Out:
# 'Priceline Pharmacy'

# %%
# Print the results
print(response["features"][0]["properties"]["name"])
print(response["features"][0]["properties"]["address_line2"])
# Out:
# Priceline Pharmacy
# 120 Queen Street, Brisbane City QLD 4000, Australia

# %% [markdown]
# ## 4. Find a pet shop within a 5km radius from the Sydney Opera House.

# %%
# Set the geographical coordinates for the Sydney Opera House
latitude = -33.85729805
longitude = 151.21512338473752

# Set the parameters for the type of place
categories = "commercial.pet"
radius = 5000

# Set the parameters for the type of search
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    "limit":limit,
    "filter":filters,
    "bias":bias,
    "apiKey":geoapify_key    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
response
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Healthy Everyday Pets',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Council of the City of Sydney',
#     'postcode': '2011',
#     'suburb': 'Elizabeth Bay',
#     'street': 'Elizabeth Bay Road',
#     'housenumber': '43-47',
#     'lon': 151.227859,
#     'lat': -33.872023,
#     'state_code': 'NSW',
#     'formatted': 'Healthy Everyday Pets, 43-47 Elizabeth Bay Road, Elizabeth Bay NSW 2011, Australia',
#     'address_line1': 'Healthy Everyday Pets',
#     'address_line2': '43-47 Elizabeth Bay Road, Elizabeth Bay NSW 2011, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Healthy Everyday Pets',
#       'shop': 'pet',
#       'osm_id': 10580904979,
#       'osm_type': 'n'}},
#     'distance': 2014,
#     'place_id': '512c23f59e4ae76240592e771c739eef40c0f00103f90113ccab76020000009203154865616c7468792045766572796461792050657473'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.22785899999997, -33.87202299966735]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Petbarn',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Council of the City of Sydney',
#     'postcode': '2010',
#     'district': 'Strawberry Hills',
#     'suburb': 'Surry Hills',
#     'street': 'Foveaux Street',
#     'lon': 151.2098816,
#     'lat': -33.8842194,
#     'state_code': 'NSW',
#     'formatted': 'Petbarn, Foveaux Street, Surry Hills NSW 2010, Australia',
#     'address_line1': 'Petbarn',
#     'address_line2': 'Foveaux Street, Surry Hills NSW 2010, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Petbarn',
#       'shop': 'pet',
#       'osm_id': 10948424184,
#       'osm_type': 'n'}},
#     'distance': 3025,
#     'place_id': '5107019e59b7e6624059df08ee192ef140c0f00103f901f8b1938c020000009203075065746261726e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.2098816, -33.88421939966951]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Petbarn',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Woollahra Municipal Council',
#     'postcode': '2028',
#     'district': 'Eastern Suburbs',
#     'suburb': 'Double Bay',
#     'street': 'Kiaora Road',
#     'lon': 151.2444929,
#     'lat': -33.8774433,
#     'state_code': 'NSW',
#     'formatted': 'Petbarn, Kiaora Road, Double Bay NSW 2028, Australia',
#     'address_line1': 'Petbarn',
#     'address_line2': 'Kiaora Road, Double Bay NSW 2028, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Petbarn',
#       'shop': 'pet',
#       'osm_id': 4925657661,
#       'osm_type': 'n'}},
#     'distance': 3518,
#     'place_id': '515533c6e2d2e7624059bb15e20f50f040c0f00103f9013d929725010000009203075065746261726e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.24449289999998, -33.87744329966832]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Petbarn',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'North Sydney Council',
#     'postcode': '2065',
#     'district': 'Lower North Shore',
#     'neighbourhood': 'Crows Nest Junction',
#     'suburb': 'Crows Nest',
#     'street': 'Willoughby Road',
#     'housenumber': '160',
#     'lon': 151.200736,
#     'lat': -33.822833,
#     'state_code': 'NSW',
#     'formatted': 'Petbarn, 160 Willoughby Road, Crows Nest NSW 2065, Australia',
#     'address_line1': 'Petbarn',
#     'address_line2': '160 Willoughby Road, Crows Nest NSW 2065, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Petbarn',
#       'shop': 'pet',
#       'brand': 'Petbarn',
#       'osm_id': 2625901404,
#       'website': 'https://www.petbarn.com.au/store-finder/crows-nest',
#       'operator': 'Petbarn',
#       'osm_type': 'n',
#       'addr:state': 'NSW',
#       'addr:street': 'Willoughby Road',
#       'addr:suburb': 'Crows Nest',
#       'addr:country': 'AU',
#       'addr:postcode': 2065,
#       'brand:wikidata': 'Q104746468',
#       'addr:housenumber': 160}},
#     'distance': 4048,
#     'place_id': '512864e76d6ce662405943cd7b9752e940c0f00103f9015c13849c000000009203075065746261726e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.200736, -33.82283299965868]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Pet O',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Council of the City of Sydney',
#     'postcode': '2038',
#     'district': 'Inner West',
#     'suburb': 'Annandale',
#     'street': 'The Crescent',
#     'housenumber': '1A',
#     'lon': 151.1758722,
#     'lat': -33.8760765,
#     'state_code': 'NSW',
#     'formatted': 'Pet O, 1A The Crescent, Annandale NSW 2038, Australia',
#     'address_line1': 'Pet O',
#     'address_line2': '1A The Crescent, Annandale NSW 2038, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Pet O',
#       'shop': 'pet',
#       'osm_id': 7726482861,
#       'website': 'https://peto.com.au/',
#       'osm_type': 'n',
#       'addr:street': 'The Crescent',
#       'addr:housenumber': '1A'}},
#     'distance': 4187,
#     'place_id': '51d168bcbea0e56240592c6f554623f040c0f00103f901adc588cc01000000920305506574204f'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.1758722, -33.87607649966807]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Dogue',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Waverley Council',
#     'postcode': '2022',
#     'district': 'Eastern Suburbs',
#     'suburb': 'Bondi Junction',
#     'street': 'Oxford Street',
#     'lon': 151.2436647,
#     'lat': -33.8905695,
#     'state_code': 'NSW',
#     'formatted': 'Dogue, Oxford Street, Bondi Junction NSW 2022, Australia',
#     'address_line1': 'Dogue',
#     'address_line2': 'Oxford Street, Bondi Junction NSW 2022, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Dogue',
#       'shop': 'pet',
#       'osm_id': 5902886018,
#       'osm_type': 'n'}},
#     'distance': 4538,
#     'place_id': '5112b6e919cce762405945f36d2efef140c0f00103f90182e4d65f01000000920305446f677565'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.2436647, -33.890569499670654]}}]}

# %%
response['features'][0]['properties']
# Out:
# {'name': 'Healthy Everyday Pets',
#  'country': 'Australia',
#  'country_code': 'au',
#  'state': 'New South Wales',
#  'city': 'Sydney',
#  'municipality': 'Council of the City of Sydney',
#  'postcode': '2011',
#  'suburb': 'Elizabeth Bay',
#  'street': 'Elizabeth Bay Road',
#  'housenumber': '43-47',
#  'lon': 151.227859,
#  'lat': -33.872023,
#  'state_code': 'NSW',
#  'formatted': 'Healthy Everyday Pets, 43-47 Elizabeth Bay Road, Elizabeth Bay NSW 2011, Australia',
#  'address_line1': 'Healthy Everyday Pets',
#  'address_line2': '43-47 Elizabeth Bay Road, Elizabeth Bay NSW 2011, Australia',
#  'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#  'details': [],
#  'datasource': {'sourcename': 'openstreetmap',
#   'attribution': '© OpenStreetMap contributors',
#   'license': 'Open Database Licence',
#   'url': 'https://www.openstreetmap.org/copyright',
#   'raw': {'name': 'Healthy Everyday Pets',
#    'shop': 'pet',
#    'osm_id': 10580904979,
#    'osm_type': 'n'}},
#  'distance': 2014,
#  'place_id': '512c23f59e4ae76240592e771c739eef40c0f00103f90113ccab76020000009203154865616c7468792045766572796461792050657473'}

# %%
# Print the results
print(response["features"][0]["properties"]["name"])
print(response["features"][0]["properties"]["address_line2"])
# Out:
# Healthy Everyday Pets
# 43-47 Elizabeth Bay Road, Elizabeth Bay NSW 2011, Australia

# %% [markdown]
# ## 5. Find the nearest dentist to your house.
#
# > **Hint:** Use Geoapify Geocode to find your latitude and Geoapify Places to find the dentist.

# %%
# Geoapify Geocode to find latitude and longitude
my_address = "1309 Hay St, West Perth WA 6005, Australia"

params = {
    "text": my_address,
    "apiKey": geoapify_key
}

# Build URL using the geocode endpoint
base_url = "https://api.geoapify.com/v1/geocode/search"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
response
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright'},
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Western Australia',
#     'county': 'City of Perth',
#     'city': 'Perth',
#     'postcode': '6005',
#     'suburb': 'West Perth',
#     'street': 'Hay Street',
#     'housenumber': '1309',
#     'lon': 115.8387213036199,
#     'lat': -31.9477365,
#     'state_code': 'WA',
#     'formatted': '1309 Hay Street, West Perth WA 6005, Australia',
#     'address_line1': '1309 Hay Street',
#     'address_line2': 'West Perth WA 6005, Australia',
#     'category': 'building',
#     'timezone': {'name': 'Australia/Perth',
#      'offset_STD': '+08:00',
#      'offset_STD_seconds': 28800,
#      'offset_DST': '+08:00',
#      'offset_DST_seconds': 28800,
#      'abbreviation_STD': 'AWST',
#      'abbreviation_DST': 'AWST'},
#     'plus_code': '4PWQ3R2Q+WF',
#     'plus_code_short': '3R2Q+WF, 6005 Perth, Australia',
#     'result_type': 'building',
#     'rank': {'importance': 0.31001,
#      'popularity': 4.404184743525478,
#      'confidence': 1,
#      'confidence_city_level': 1,
#      'confidence_street_level': 1,
#      'match_type': 'full_match'},
#     'place_id': '5162601e9cadf55c4059bbb9f8db9ef23fc0f00102f90162fb9f0200000000c00203'},
#    'geometry': {'type': 'Point',
#     'coordinates': [115.8387213036199, -31.9477365]},
#    'bbox': [115.8386495, -31.9478073, 115.8388058, -31.9476898]},
#   {'type': 'Feature',
#    'properties': {'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright'},
#     'name': 'Sage Hotel West Perth',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Western Australia',
#     'county': 'City of Perth',
#     'city': 'Perth',
#     'postcode': '6005',
#     'suburb': 'West Perth',
#     'street': 'Hay Street',
#     'housenumber': '1309',
#     'lon': 115.8387172,
#     'lat': -31.947806,
#     'state_code': 'WA',
#     'formatted': 'Sage Hotel West Perth, 1309 Hay Street, West Perth WA 6005, Australia',
#     'address_line1': 'Sage Hotel West Perth',
#     'address_line2': '1309 Hay Street, West Perth WA 6005, Australia',
#     'category': 'accommodation.hotel',
#     'timezone': {'name': 'Australia/Perth',
#      'offset_STD': '+08:00',
#      'offset_STD_seconds': 28800,
#      'offset_DST': '+08:00',
#      'offset_DST_seconds': 28800,
#      'abbreviation_STD': 'AWST',
#      'abbreviation_DST': 'AWST'},
#     'plus_code': '4PWQ3R2Q+VF',
#     'plus_code_short': '3R2Q+VF, 6005 Perth, Australia',
#     'result_type': 'amenity',
#     'rank': {'importance': 0.31001,
#      'popularity': 4.404184743525478,
#      'confidence': 1,
#      'confidence_city_level': 1,
#      'confidence_street_level': 1,
#      'match_type': 'inner_part'},
#     'place_id': '51ef25e88aadf55c4059dcf3fc69a3f23fc0f00103f901313d270501000000c002019203155361676520486f74656c2057657374205065727468'},
#    'geometry': {'type': 'Point', 'coordinates': [115.8387172, -31.947806]},
#    'bbox': [115.8386672, -31.947856, 115.8387672, -31.947756]}],
#  'query': {'text': '1309 Hay St, West Perth WA 6005, Australia',
#   'parsed': {'housenumber': '1309',
#    'street': 'hay st',
#    'suburb': 'west perth',
#    'postcode': '6005',
#    'state': 'wa',
#    'country': 'australia',
#    'expected_type': 'building'}}}

# %%
# Extract lat/lon
lat = response["features"][0]["properties"]["lat"]
lon = response["features"][0]["properties"]["lon"]

# Print results
print(f"{my_address}: {lat}, {lon}")
# Out:
# 1309 Hay St, West Perth WA 6005, Australia: -31.9477365, 115.8387213036199

# %%
# Set the geographical coordinates for my home
latitude = -31.9477365
longitude = 115.8387213036199

# Set the parameters for the type of place
categories = "healthcare.dentist"

# Set the parameters for the type of search
bias = f"proximity:{longitude},{latitude}"
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    "limit":limit,
    "bias":bias,
    "apiKey":geoapify_key    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "bbox": [
#                 115.8386495,
#                 -31.9478073,
#                 115.8388058,
#                 -31.9476898
#             ],
#             "geometry": {
#                 "coordinates": [
#                     115.8387213036199,
#                     -31.9477365
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "1309 Hay Street",
#                 "address_line2": "West Perth WA 6005, Australia",
#                 "category": "building",
#                 "city": "Perth",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "City of Perth",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "1309 Hay Street, West Perth WA 6005, Australia",
#                 "housenumber": "1309",
#                 "lat": -31.9477365,
#                 "lon": 115.8387213036199,
#                 "place_id": "5162601e9cadf55c4059bbb9f8db9ef23fc0f00102f90162fb9f0200000000c00203",
#                 "plus_code": "4PWQ3R2Q+WF",
#                 "plus_code_short": "3R2Q+WF, 6005 Perth, Australia",
#                 "postcode": "6005",
#                 "rank": {
#                     "confidence": 1,
#                     "confidence_city_level": 1,
#                     "confidence_street_level": 1,
#                     "importance": 0.31001,
#                     "match_type": "full_match",
#                     "popularity": 4.404184743525478
#                 },
#                 "result_type": "building",
#                 "state": "Western Australia",
#                 "state_code": "WA",
#                 "street": "Hay Street",
#                 "suburb": "West Perth",
#                 "timezone": {
#                     "abbreviation_DST": "AWST",
#                     "abbreviation_STD": "AWST",
#                     "name": "Australia/Perth",
#                     "offset_DST": "+08:00",
#                     "offset_DST_seconds": 28800,
#                     "offset_STD": "+08:00",
#                     "offset_STD_seconds": 28800
#                 }
#             },
#             "type": "Feature"
#         },
#         {
#             "bbox": [
#                 115.8386672,
#                 -31.947856,
#                 115.8387672,
#                 -31.947756
#             ],
#             "geometry": {
#                 "coordinates": [
#                     115.8387172,
#                     -31.947806
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Sage Hotel West Perth",
#                 "address_line2": "1309 Hay Street, West Perth WA 6005, Australia",
#                 "category": "accommodation.hotel",
#                 "city": "Perth",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "City of Perth",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Sage Hotel West Perth, 1309 Hay Street, West Perth WA 6005, Australia",
#                 "housenumber": "1309",
#                 "lat": -31.947806,
#                 "lon": 115.8387172,
#                 "name": "Sage Hotel West Perth",
#                 "place_id": "51ef25e88aadf55c4059dcf3fc69a3f23fc0f00103f901313d270501000000c002019203155361676520486f74656c2057657374205065727468",
#                 "plus_code": "4PWQ3R2Q+VF",
#                 "plus_code_short": "3R2Q+VF, 6005 Perth, Australia",
#                 "postcode": "6005",
#                 "rank": {
#                     "confidence": 1,
#                     "confidence_city_level": 1,
#                     "confidence_street_level": 1,
#                     "importance": 0.31001,
#                     "match_type": "inner_part",
#                     "popularity": 4.404184743525478
#                 },
#                 "result_type": "amenity",
#                 "state": "Western Australia",
#                 "state_code": "WA",
#                 "street": "Hay Street",
#                 "suburb": "West Perth",
#                 "timezone": {
#                     "abbreviation_DST": "AWST",
#                     "abbreviation_STD": "AWST",
#                     "name": "Australia/Perth",
#                     "offset_DST": "+08:00",
#                     "offset_DST_seconds": 28800,
#                     "offset_STD": "+08:00",
#                     "offset_STD_seconds": 28800
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "country": "australia",
#             "expected_type": "building",
#             "housenumber": "1309",
#             "postcode": "6005",
#             "state": "wa",
#             "street": "hay st",
#             "suburb": "west perth"
#         },
#         "text": "1309 Hay St, West Perth WA 6005, Australia"
#     },
#     "type": "FeatureCollection"
# }

# %%
# Print the results
print(response["features"][0]["properties"]["name"])
print(response["features"][0]["properties"]["address_line2"])
# Out:
# West Perth Dental Centre
# 39 Colin Street, West Perth WA 6005, Australia

# %% [markdown]
# ## 6. Bonus: Find the names and addresses of the five nearest restaurants with internet access in your home city area.
#
# > **Hint:** Read about the `proximity` bias to order the results from the nearest to the farest place. Also, read about the `conditions` to identify places that provide internet access.

# %%
# Set the geographical coordinates for my home
latitude = -31.9477365
longitude = 115.8387213036199

# Set the parameters for the type of place
categories = "catering.restaurant"
conditions = "internet_access"

# Set the parameters for the type of search
bias = f"proximity:{longitude},{latitude}"
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    "conditions":conditions,
    "limit":limit,
    "bias":bias,
    "apiKey":geoapify_key    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     115.85034679999997,
#                     -31.951272899405485
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Cespresso CBD West",
#                 "address_line2": "996 Hay Street, Perth WA 6000, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "internet_access"
#                 ],
#                 "city": "Perth",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "City of Perth",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:country": "AU",
#                         "addr:housenumber": 996,
#                         "addr:postcode": 6000,
#                         "addr:state": "WA",
#                         "addr:street": "Hay St",
#                         "addr:suburb": "Perth",
#                         "addr:unit": 5,
#                         "amenity": "restaurant",
#                         "delivery": "yes",
#                         "internet_access": "yes",
#                         "name": "Cespresso CBD West",
#                         "opening_hours": "Mo-Fr 06:00-17:00; Sa 07:00-12:00",
#                         "osm_id": 8148139342,
#                         "osm_type": "n",
#                         "phone": "+61 8 9226 2006",
#                         "takeaway": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "distance": 1167,
#                 "district": "Perth",
#                 "formatted": "Cespresso CBD West, 996 Hay Street, Perth WA 6000, Australia",
#                 "housenumber": "996",
#                 "lat": -31.9512729,
#                 "lon": 115.8503468,
#                 "name": "Cespresso CBD West",
#                 "place_id": "518510fc146cf65c40598584e89e86f33fc0f00103f9014ebdaae50100000092031243657370726573736f204342442057657374",
#                 "postcode": "6000",
#                 "state": "Western Australia",
#                 "state_code": "WA",
#                 "street": "Hay Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     115.8221609,
#                     -31.946109299405034
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "El Peruvian Food Co.",
#                 "address_line2": "Outridge Crescent, Subiaco WA 6008, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "internet_access",
#                     "internet_access.for_customers"
#                 ],
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "City of Subiaco",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "check_date": "2022-11-11",
#                         "internet_access": "wlan",
#                         "internet_access:fee": "customers",
#                         "name": "El Peruvian Food Co.",
#                         "osm_id": 9948850105,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "distance": 1576,
#                 "formatted": "El Peruvian Food Co., Outridge Crescent, Subiaco WA 6008, Australia",
#                 "lat": -31.9461093,
#                 "lon": 115.8221609,
#                 "name": "El Peruvian Food Co.",
#                 "place_id": "513263c0489ef45c4059d762133834f23fc0f00103f901b967ff5002000000920314456c20506572757669616e20466f6f6420436f2e",
#                 "postcode": "6008",
#                 "state": "Western Australia",
#                 "state_code": "WA",
#                 "street": "Outridge Crescent",
#                 "suburb": "Subiaco"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     115.8579722,
#                     -31.948660299405248
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "PappaRich",
#                 "address_line2": "101 James Street, Northbridge WA 6000, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.malay",
#                     "catering.restaurant.malaysian",
#                     "internet_access",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Perth",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "City of Perth",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Perth",
#                         "addr:housenumber": 101,
#                         "addr:postcode": 6000,
#                         "addr:state": "WA",
#                         "addr:street": "James Street",
#                         "addr:suburb": "Northbridge",
#                         "amenity": "restaurant",
#                         "brand": "PappaRich",
#                         "brand:wikidata": "Q95721282",
#                         "cuisine": "malaysian",
#                         "internet_access": "wlan",
#                         "name": "PappaRich",
#                         "opening_hours": "Mo-Th 10:30-21:00; Fr-Sa 10:30-22:00; Su 10:30-21:00",
#                         "osm_id": 492489136,
#                         "osm_type": "n",
#                         "phone": "+61 8 6361 1766",
#                         "smoking": "no",
#                         "website": "https://www.papparich.net.au/",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "distance": 1823,
#                 "formatted": "PappaRich, 101 James Street, Northbridge WA 6000, Australia",
#                 "housenumber": "101",
#                 "lat": -31.9486603,
#                 "lon": 115.8579722,
#                 "name": "PappaRich",
#                 "place_id": "5124f83a04e9f65c405988f5c066dbf23fc0f00103f901b0c95a1d00000000920309506170706152696368",
#                 "postcode": "6000",
#                 "state": "Western Australia",
#                 "state_code": "WA",
#                 "street": "James Street",
#                 "suburb": "Northbridge"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     115.8606176,
#                     -31.954194199405755
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Le Vietnam",
#                 "address_line2": "80 Barrack Street, Perth WA 6000, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.vietnamese",
#                     "internet_access"
#                 ],
#                 "city": "Perth",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "City of Perth",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "cuisine": "sandwich;vietnamese",
#                         "internet_access": "wlan",
#                         "name": "Le Vietnam",
#                         "osm_id": 5068984522,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 2190,
#                 "district": "Perth",
#                 "formatted": "Le Vietnam, 80 Barrack Street, Perth WA 6000, Australia",
#                 "housenumber": "80",
#                 "lat": -31.9541942,
#                 "lon": 115.8606176,
#                 "name": "Le Vietnam",
#                 "place_id": "512b97d75b14f75c40590a7b301246f43fc0f00103f901ca90222e0100000092030a4c6520566965746e616d",
#                 "postcode": "6000",
#                 "state": "Western Australia",
#                 "state_code": "WA",
#                 "street": "Barrack Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     115.81360999999997,
#                     -31.97257529940747
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Burgermeister",
#                 "address_line2": "170B Hampden Road, Nedlands WA 6009, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.burger",
#                     "internet_access"
#                 ],
#                 "city": "Perth",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "City of Perth",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": "170B",
#                         "addr:postcode": 6009,
#                         "addr:street": "Hampden Road",
#                         "amenity": "restaurant",
#                         "cuisine": "burger;hot_dog",
#                         "internet_access": "wlan",
#                         "name": "Burgermeister",
#                         "name:en": "Burgermeister",
#                         "opening_hours": "Mo-Sa 11:00-20:00; Su 17:00-20:00",
#                         "osm_id": 4639180589,
#                         "osm_type": "n",
#                         "phone": "+61 8 9389 9225",
#                         "website": "http://www.burgermeister.com"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "distance": 3636,
#                 "formatted": "Burgermeister, 170B Hampden Road, Nedlands WA 6009, Australia",
#                 "housenumber": "170B",
#                 "lat": -31.9725753,
#                 "lon": 115.81361,
#                 "name": "Burgermeister",
#                 "place_id": "51b36cad2f12f45c40593ddadfb1faf83fc0f00103f9012d4784140100000092030d4275726765726d656973746572",
#                 "postcode": "6009",
#                 "state": "Western Australia",
#                 "state_code": "WA",
#                 "street": "Hampden Road",
#                 "suburb": "Nedlands"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     115.89436170778043,
#                     -31.95899856322648
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Crown Towers, Perth",
#                 "address_line2": "Bolton Avenue, Burswood WA 6100, Australia",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant",
#                     "internet_access"
#                 ],
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "Town of Victoria Park",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:street": "Crown Towers, Great Eastern Hwy, Burswood",
#                         "air_conditioning": "yes",
#                         "amenity": "restaurant",
#                         "bar": "yes",
#                         "brand": "Crown",
#                         "building": "yes",
#                         "building:levels": 21,
#                         "height": 105,
#                         "internet_access": "yes",
#                         "name": "Crown Towers, Perth",
#                         "operator": "Crown",
#                         "osm_id": 698207742,
#                         "osm_type": "w",
#                         "rooms": 500
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.facilities"
#                 ],
#                 "distance": 5347,
#                 "formatted": "Crown Towers, Perth, Bolton Avenue, Burswood WA 6100, Australia",
#                 "lat": -31.9592481,
#                 "lon": 115.89436217965937,
#                 "name": "Crown Towers, Perth",
#                 "place_id": "518c6de3383df95c4059fef709ee80f53fc0f00102f901fecd9d290000000092031343726f776e20546f776572732c205065727468",
#                 "postcode": "6100",
#                 "state": "Western Australia",
#                 "state_code": "WA",
#                 "street": "Bolton Avenue",
#                 "suburb": "Burswood"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     115.8973567,
#                     -31.994795899409542
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Peace'Za",
#                 "address_line2": "Etwell Street, East Victoria Park WA 6101, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.pizza",
#                     "gluten_free",
#                     "internet_access",
#                     "vegan",
#                     "vegan.only"
#                 ],
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "Town of Victoria Park",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "contact:facebook": "https://www.facebook.com/peacezaperth/",
#                         "contact:instagram": "https://www.instagram.com/peacezaperth/",
#                         "cuisine": "pizza",
#                         "diet:gluten_free": "yes",
#                         "diet:vegan": "only",
#                         "internet_access": "wlan",
#                         "name": "Peace'Za",
#                         "osm_id": 4983971925,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 7612,
#                 "formatted": "Peace'Za, Etwell Street, East Victoria Park WA 6101, Australia",
#                 "lat": -31.9947959,
#                 "lon": 115.8973567,
#                 "name": "Peace'Za",
#                 "place_id": "512dd6cb4a6ef95c4059ad28aef1aafe3fc0f00103f90155601129010000009203085065616365275a61",
#                 "postcode": "6101",
#                 "state": "Western Australia",
#                 "state_code": "WA",
#                 "street": "Etwell Street",
#                 "suburb": "East Victoria Park"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     115.761163,
#                     -31.99797159940984
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Vans Deli",
#                 "address_line2": "3 Napoleon Street, Cottesloe WA 6011, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "internet_access"
#                 ],
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "Town of Cottesloe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 3,
#                         "addr:postcode": 6011,
#                         "addr:street": "Napoleon Street",
#                         "amenity": "restaurant",
#                         "internet_access": "wlan",
#                         "name": "Vans Deli",
#                         "opening_hours": "Mo-Su 06:30-22:00",
#                         "operator": "Kevin",
#                         "osm_id": 4658312889,
#                         "osm_type": "n",
#                         "phone": "+61 8 9384 0696"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "distance": 9207,
#                 "formatted": "Vans Deli, 3 Napoleon Street, Cottesloe WA 6011, Australia",
#                 "housenumber": "3",
#                 "lat": -31.9979716,
#                 "lon": 115.761163,
#                 "name": "Vans Deli",
#                 "place_id": "5137fb03e5b6f05c405955cd15117bff3fc0f00103f901b936a8150100000092030956616e732044656c69",
#                 "postcode": "6011",
#                 "state": "Western Australia",
#                 "state_code": "WA",
#                 "street": "Napoleon Street",
#                 "suburb": "Cottesloe"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     115.7454219,
#                     -32.05627019941541
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Bread In Common",
#                 "address_line2": "43 Pakenham Street, Fremantle WA 6160, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "internet_access"
#                 ],
#                 "city": "Fremantle",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "City of Fremantle",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Fremantle",
#                         "addr:housenumber": 43,
#                         "addr:postcode": 6160,
#                         "addr:street": "Pakenham Street",
#                         "amenity": "restaurant",
#                         "contact:instagram": "https://www.instagram.com/bread_in_common/",
#                         "email": "info@breadincommon.com.au",
#                         "internet_access": "wlan",
#                         "name": "Bread In Common",
#                         "opening_hours": "Mo-Fr 11:30-22:00; Sa-Su 08:00-23:00",
#                         "osm_id": 4731890527,
#                         "osm_type": "n",
#                         "phone": "+61 8 9336 1032",
#                         "website": "https://www.breadincommon.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "distance": 14918,
#                 "district": "West End",
#                 "formatted": "Bread In Common, 43 Pakenham Street, Fremantle WA 6160, Australia",
#                 "housenumber": "43",
#                 "lat": -32.0562702,
#                 "lon": 115.7454219,
#                 "name": "Bread In Common",
#                 "place_id": "51388e0efeb4ef5c4059421da5dc330740c0f00103f9015feb0a1a0100000092030f427265616420496e20436f6d6d6f6e",
#                 "postcode": "6160",
#                 "state": "Western Australia",
#                 "state_code": "WA",
#                 "street": "Pakenham Street"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %%
# Print the results
counter = 0

for place in response["features"]:
    print(f"Restaurant {counter+1}:")
    print(place["properties"]["name"])
    print(place["properties"]["address_line2"])
    print("*"*20)
    counter = counter + 1
    if counter == 5:
        break
# Out:
# Restaurant 1:
# Cespresso CBD West
# 996 Hay Street, Perth WA 6000, Australia
# ********************
# Restaurant 2:
# El Peruvian Food Co.
# Outridge Crescent, Subiaco WA 6008, Australia
# ********************
# Restaurant 3:
# PappaRich
# 101 James Street, Northbridge WA 6000, Australia
# ********************
# Restaurant 4:
# Le Vietnam
# 80 Barrack Street, Perth WA 6000, Australia
# ********************
# Restaurant 5:
# Burgermeister
# 170B Hampden Road, Nedlands WA 6009, Australia
# ********************
