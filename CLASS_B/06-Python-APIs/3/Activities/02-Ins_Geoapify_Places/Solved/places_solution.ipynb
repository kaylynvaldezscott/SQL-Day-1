# %% [markdown]
# # Geoapify Places Demo

# %%
# Dependencies
import requests
import json

# Import the API key
from config import geoapify_key

# %%
geoapify_key
# Out:
# '4a987a25d5c0407a8b6de8933da491dc'

# %%
import requests

url = "https://api.geoapify.com/v2/places?categories=catering.restaurant&conditions=vegetarian&filter=place:51234e57c6dbd853c059cb633c8b89dc4540f00101f90173f2040000000000c00209920307546f726f6e746f&lang=en&limit=20&apiKey=4a987a25d5c0407a8b6de8933da491dc"        
response = requests.get(url)
print(response.json())
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'govindas', 'country': 'Canada', 'country_code': 'ca', 'state': 'Ontario', 'county': 'Golden Horseshoe', 'city': 'Old Toronto', 'postcode': 'M5R 2J6', 'district': 'Yorkville', 'suburb': 'University—Rosedale', 'street': 'Avenue Road', 'housenumber': '243', 'lon': -79.39691132197069, 'lat': 43.67698495, 'state_code': 'ON', 'formatted': 'govindas, 243 Avenue Road, Old Toronto, ON M5R 2J6, Canada', 'address_line1': 'govindas', 'address_line2': '243 Avenue Road, Old Toronto, ON M5R 2J6, Canada', 'categories': ['building', 'building.catering', 'catering', 'catering.restaurant', 'gluten_free', 'vegan', 'vegetarian', 'vegetarian.only'], 'details': ['details', 'details.catering', 'details.contact', 'details.facilities', 'details.wiki_and_media'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database Licence', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'govindas', 'email': 'govindastoronto@gmail.com', 'image': 'https://www.govindas.ca/img/slider/sliderbg1.jpg', 'layer': -1, 'phone': '+1 888-218-1040', 'osm_id': 853816640, 'amenity': 'restaurant', 'cuisine': 'indian;fusion;bengali', 'website': 'https://www.govindas.ca/', 'building': 'yes', 'delivery': 'yes', 'osm_type': 'w', 'addr:city': 'Toronto', 'diet:vegan': 'yes', 'addr:street': 'Avenue Road', 'description': "Govinda's is a vegan/vegetarian restaurant serving fusion cuisine located in a historic building in downtown Toronto, minutes from Yorkville. Whether for an intimate get together or a large gathering, Govinda's has the setting for you. Govinda's has a bea", 'addr:postcode': 'M5R2J6', 'addr:province': 'on', 'opening_hours': 'Mo-Sa 12:00-14:30,18:00-21:00; Su 17:00-20:00', 'diet:vegetarian': 'only', 'addr:housenumber': 243, 'air_conditioning': 'yes', 'diet:gluten_free': 'yes', 'opening_hours:covid19': 'open'}}, 'place_id': '519101f00a67d953c059e2db4023a8d64540f00102f9014035e43200000000920308676f76696e646173'}, 'geometry': {'type': 'Point', 'coordinates': [-79.39691422880266, 43.67700615565242]}}, {'type': 'Feature', 'properties': {'name': 'Fresh', 'country': 'Canada', 'country_code': 'ca', 'state': 'Ontario', 'county': 'Golden Horseshoe', 'city': 'Old Toronto', 'postcode': 'M5V 2L7', 'district': 'Queen West', 'suburb': 'Spadina—Fort York', 'street': 'Spadina Avenue', 'housenumber': '147', 'lon': -79.39565796966185, 'lat': 43.6481171, 'state_code': 'ON', 'formatted': 'Fresh, 147 Spadina Avenue, Old Toronto, ON M5V 2L7, Canada', 'address_line1': 'Fresh', 'address_line2': '147 Spadina Avenue, Old Toronto, ON M5V 2L7, Canada', 'categories': ['catering', 'catering.restaurant', 'vegan', 'vegetarian', 'vegetarian.only', 'wheelchair', 'wheelchair.yes'], 'details': ['details', 'details.catering', 'details.contact', 'details.facilities'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database Licence', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Fresh', 'phone': '+1-416-599-4442', 'osm_id': 536124111, 'amenity': 'restaurant', 'website': 'https://freshrestaurants.ca/', 'osm_type': 'w', 'addr:city': 'Toronto', 'diet:vegan': 'yes', 'wheelchair': 'yes', 'addr:street': 'Spadina Avenue', 'addr:postcode': 'M5V 2L7', 'opening_hours': 'Mo-Fr 11:30-22:00, Sa-Su 10:30-22:00', 'diet:vegetarian': 'only', 'outdoor_seating': 'yes', 'addr:housenumber': 147, 'wheelchair:description': 'StopGap ramp'}}, 'place_id': '51994a657252d953c059785db282f5d24540f00102f901cf9af41f000000009203054672657368'}, 'geometry': {'type': 'Point', 'coordinates': [-79.39565715686548, 43.648117386905994]}}, {'type': 'Feature', 'properties': {'name': 'Fresh', 'country': 'Canada', 'country_code': 'ca', 'state': 'Ontario', 'county': 'Golden Horseshoe', 'city': 'Old Toronto', 'postcode': 'M6J 1G3', 'district': 'West Queen West', 'suburb': 'Spadina—Fort York', 'street': 'Queen Str ...

# %%
latitude = -33.8698439
longitude = 151.2082848

# %%
radius = 8000
# Set the parameters for the type of search
filters = f"circle:{longitude},{latitude},{radius}"
filters='place:51234e57c6dbd853c059cb633c8b89dc4540f00101f90173f2040000000000c00209920307546f726f6e746f'

# %%
filters
# Out:
# 'place:51234e57c6dbd853c059cb633c8b89dc4540f00101f90173f2040000000000c00209920307546f726f6e746f'

# %%
# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# set up a parameters dictionary
params = {
    "categories":'catering.restaurant',
    "conditions":'vegetarian',
    "limit":'20',
    "lang":'en',
    "filter":filters,
    "apiKey":geoapify_key    
}

# %%
# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
# convert response to json
places_data = response.json()
places_data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'govindas',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M5R 2J6',
#     'district': 'Yorkville',
#     'suburb': 'University—Rosedale',
#     'street': 'Avenue Road',
#     'housenumber': '243',
#     'lon': -79.39691132197069,
#     'lat': 43.67698495,
#     'state_code': 'ON',
#     'formatted': 'govindas, 243 Avenue Road, Old Toronto, ON M5R 2J6, Canada',
#     'address_line1': 'govindas',
#     'address_line2': '243 Avenue Road, Old Toronto, ON M5R 2J6, Canada',
#     'categories': ['building',
#      'building.catering',
#      'catering',
#      'catering.restaurant',
#      'gluten_free',
#      'vegan',
#      'vegetarian',
#      'vegetarian.only'],
#     'details': ['details',
#      'details.catering',
#      'details.contact',
#      'details.facilities',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'govindas',
#       'email': 'govindastoronto@gmail.com',
#       'image': 'https://www.govindas.ca/img/slider/sliderbg1.jpg',
#       'layer': -1,
#       'phone': '+1 888-218-1040',
#       'osm_id': 853816640,
#       'amenity': 'restaurant',
#       'cuisine': 'indian;fusion;bengali',
#       'website': 'https://www.govindas.ca/',
#       'building': 'yes',
#       'delivery': 'yes',
#       'osm_type': 'w',
#       'addr:city': 'Toronto',
#       'diet:vegan': 'yes',
#       'addr:street': 'Avenue Road',
#       'description': "Govinda's is a vegan/vegetarian restaurant serving fusion cuisine located in a historic building in downtown Toronto, minutes from Yorkville. Whether for an intimate get together or a large gathering, Govinda's has the setting for you. Govinda's has a bea",
#       'addr:postcode': 'M5R2J6',
#       'addr:province': 'on',
#       'opening_hours': 'Mo-Sa 12:00-14:30,18:00-21:00; Su 17:00-20:00',
#       'diet:vegetarian': 'only',
#       'addr:housenumber': 243,
#       'air_conditioning': 'yes',
#       'diet:gluten_free': 'yes',
#       'opening_hours:covid19': 'open'}},
#     'place_id': '519101f00a67d953c059e2db4023a8d64540f00102f9014035e43200000000920308676f76696e646173'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.39691422880266, 43.67700615565242]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Fresh',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M5V 2L7',
#     'district': 'Queen West',
#     'suburb': 'Spadina—Fort York',
#     'street': 'Spadina Avenue',
#     'housenumber': '147',
#     'lon': -79.39565796966185,
#     'lat': 43.6481171,
#     'state_code': 'ON',
#     'formatted': 'Fresh, 147 Spadina Avenue, Old Toronto, ON M5V 2L7, Canada',
#     'address_line1': 'Fresh',
#     'address_line2': '147 Spadina Avenue, Old Toronto, ON M5V 2L7, Canada',
#     'categories': ['catering',
#      'catering.restaurant',
#      'vegan',
#      'vegetarian',
#      'vegetarian.only',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.catering',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Fresh',
#       'phone': '+1-416-599-4442',
#       'osm_id': 536124111,
#       'amenity': 'restaurant',
#       'website': 'https://freshrestaurants.ca/',
#       'osm_type': 'w',
#       'addr:city': 'Toronto',
#       'diet:vegan': 'yes',
#       'wheelchair': 'yes',
#       'addr:street': 'Spadina Avenue',
#       'addr:postcode': 'M5V 2L7',
#       'opening_hours': 'Mo-Fr 11:30-22:00, Sa-Su 10:30-22:00',
#       'diet:vegetarian': 'only',
#       'outdoor_seating': 'yes',
#       'addr:housenumber': 147,
#       'wheelchair:description': 'StopGap ramp'}},
#     'place_id': '51994a657252d953c059785db282f5d24540f00102f901cf9af41f000000009203054672657368'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.39565715686548, 43.648117386905994]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Fresh',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M6J 1G3',
#     'district': 'West Queen West',
#     'suburb': 'Spadina—Fort York',
#     'street': 'Queen Street West',
#     'housenumber': '894',
#     'lon': -79.4150006547298,
#     'lat': 43.645165500000004,
#     'state_code': 'ON',
#     'formatted': 'Fresh, 894 Queen Street West, Old Toronto, ON M6J 1G3, Canada',
#     'address_line1': 'Fresh',
#     'address_line2': '894 Queen Street West, Old Toronto, ON M6J 1G3, Canada',
#     'categories': ['building',
#      'building.catering',
#      'building.commercial',
#      'catering',
#      'catering.restaurant',
#      'vegan',
#      'vegetarian',
#      'vegetarian.only',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.catering',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Fresh',
#       'phone': '+1-416-599-4442',
#       'osm_id': 536134194,
#       'amenity': 'restaurant',
#       'website': 'https://freshrestaurants.ca/',
#       'building': 'retail',
#       'osm_type': 'w',
#       'addr:city': 'Toronto',
#       'diet:vegan': 'yes',
#       'wheelchair': 'yes',
#       'addr:street': 'Queen Street West',
#       'addr:postcode': 'M6J 1G3',
#       'opening_hours': 'Mo-Fr 11:30-22:00, Sa-Su 10:30-22:00',
#       'diet:vegetarian': 'only',
#       'addr:housenumber': 894,
#       'wheelchair:description': 'No automatic door'}},
#     'place_id': '518e39e3518fda53c059acb461c794d24540f00102f90132c2f41f000000009203054672657368'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.41499755086826, 43.645165369708906]}},
#   {'type': 'Feature',
#    'properties': {'name': 'La Cubana',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M6R 2M9',
#     'district': 'Roncesvalles',
#     'suburb': 'Parkdale—High Park',
#     'street': 'Roncesvalles Avenue',
#     'housenumber': '392',
#     'lon': -79.450988,
#     'lat': 43.6509077,
#     'state_code': 'ON',
#     'formatted': 'La Cubana, 392 Roncesvalles Avenue, Old Toronto, ON M6R 2M9, Canada',
#     'address_line1': 'La Cubana',
#     'address_line2': '392 Roncesvalles Avenue, Old Toronto, ON M6R 2M9, Canada',
#     'categories': ['catering',
#      'catering.restaurant',
#      'catering.restaurant.cuban',
#      'production',
#      'production.brewery',
#      'vegan',
#      'vegetarian',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.catering',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'La Cubana',
#       'phone': '+1-416-538-7500',
#       'osm_id': 3879067756,
#       'amenity': 'restaurant',
#       'cuisine': 'cuban',
#       'website': 'http://www.lacubana.ca/',
#       'osm_type': 'n',
#       'takeaway': 'yes',
#       'addr:city': 'Toronto',
#       'diet:meat': 'yes',
#       'diet:vegan': 'yes',
#       'wheelchair': 'yes',
#       'addr:street': 'Roncesvalles Avenue',
#       'microbrewery': 'yes',
#       'addr:postcode': 'M6R 2M9',
#       'addr:province': 'Ontario',
#       'opening_hours': 'Tu-Sa 16:00-21:00',
#       'diet:vegetarian': 'yes',
#       'addr:housenumber': 392,
#       'wheelchair:description': 'StopGap ramp'}},
#     'place_id': '51dbb8c5fcdcdc53c059b4448bf150d34540f00103f9016ce035e7000000009203094c6120437562616e61'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45098799999998, 43.65090770054067]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Regal Garden Chinese Restaurant',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M6G 1K9',
#     'district': 'Mirvish Village',
#     'suburb': 'University—Rosedale',
#     'street': 'Bloor Street West',
#     'housenumber': '643',
#     'lon': -79.415045,
#     'lat': 43.6641827,
#     'state_code': 'ON',
#     'formatted': 'Regal Garden Chinese Restaurant, 643 Bloor Street West, Old Toronto, ON M6G 1K9, Canada',
#     'address_line1': 'Regal Garden Chinese Restaurant',
#     'address_line2': '643 Bloor Street West, Old Toronto, ON M6G 1K9, Canada',
#     'categories': ['catering',
#      'catering.restaurant',
#      'catering.restaurant.chinese',
#      'vegan',
#      'vegetarian'],
#     'details': ['details',
#      'details.catering',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Regal Garden Chinese Restaurant',
#       'phone': '+1-416-530-8088',
#       'osm_id': 6357274281,
#       'amenity': 'restaurant',
#       'cuisine': 'chinese',
#       'website': 'https://www.regalgardendelivery.ca',
#       'delivery': 'yes',
#       'osm_type': 'n',
#       'takeaway': 'Tu-Sa 09:00-20:00;Su 09:00-15:00;Mo closed',
#       'addr:city': 'Toronto',
#       'diet:vegan': 'yes',
#       'addr:street': 'Bloor Street West',
#       'opening_hours': 'We-Mo 17:00-20:30',
#       'diet:vegetarian': 'yes',
#       'addr:housenumber': 643}},
#     'place_id': '519357e71890da53c059fab150f003d54540f00103f901a94eec7a0100000092031f526567616c2047617264656e204368696e6573652052657374617572616e74'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.415045, 43.66418270054051]}},
#   {'type': 'Feature',
#    'properties': {'name': 'The Hummussiah',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M5B 1Y2',
#     'district': 'Garden District',
#     'suburb': 'Toronto Centre',
#     'street': 'Bond Street',
#     'housenumber': '113',
#     'lon': -79.3785078,
#     'lat': 43.657168,
#     'state_code': 'ON',
#     'formatted': 'The Hummussiah, 113 Bond Street, Old Toronto, ON M5B 1Y2, Canada',
#     'address_line1': 'The Hummussiah',
#     'address_line2': '113 Bond Street, Old Toronto, ON M5B 1Y2, Canada',
#     'categories': ['catering',
#      'catering.restaurant',
#      'catering.restaurant.international',
#      'halal',
#      'vegan',
#      'vegetarian'],
#     'details': ['details', 'details.catering', 'details.contact'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'The Hummussiah',
#       'email': 'EAT@THEHUMMUSSIAH.COM',
#       'phone': '+1-647-505-4777',
#       'osm_id': 6676216514,
#       'amenity': 'restaurant',
#       'cuisine': 'international',
#       'website': 'https://www.thehummussiah.com',
#       'osm_type': 'n',
#       'addr:city': 'Toronto',
#       'diet:halal': 'yes',
#       'diet:vegan': 'yes',
#       'addr:street': 'Bond Street',
#       'addr:postcode': 'M5B 1Y2',
#       'opening_hours': 'Mo-Sa 10:00-20:00',
#       'diet:vegetarian': 'yes',
#       'addr:housenumber': 113}},
#     'place_id': '51fa91c77839d853c0595826bf141ed44540f00103f901c2faee8d0100000092030e5468652048756d6d757373696168'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.3785078, 43.657168000540594]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Antler Kitchen & Bar',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M6J 1Y6',
#     'suburb': 'Davenport',
#     'street': 'Dundas Street West',
#     'housenumber': '1454',
#     'lon': -79.4305576,
#     'lat': 43.649717,
#     'state_code': 'ON',
#     'formatted': 'Antler Kitchen & Bar, 1454 Dundas Street West, Old Toronto, ON M6J 1Y6, Canada',
#     'address_line1': 'Antler Kitchen & Bar',
#     'address_line2': '1454 Dundas Street West, Old Toronto, ON M6J 1Y6, Canada',
#     'categories': ['catering', 'catering.restaurant', 'vegan', 'vegetarian'],
#     'details': ['details',
#      'details.catering',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Antler Kitchen & Bar',
#       'phone': '+1-647-345-8300',
#       'osm_id': 6820739730,
#       'amenity': 'restaurant',
#       'cuisine': 'canadian;wild;seasonal',
#       'website': 'https://www.antlerkitchenbar.com',
#       'alt_name': 'Antler Kitchen & Bar',
#       'delivery': 'yes',
#       'osm_type': 'n',
#       'takeaway': 'yes',
#       'addr:city': 'Toronto',
#       'diet:meat': 'yes',
#       'diet:vegan': 'yes',
#       'addr:street': 'Dundas Street West',
#       'addr:postcode': 'M6J 1Y6',
#       'addr:province': 'Ontario',
#       'opening_hours': 'Mo closed; Tu-Fr 17:00-22:00; Sa-Su 12:00-15:00,17:00-22:00',
#       'diet:vegetarian': 'yes',
#       'addr:housenumber': 1454}},
#     'place_id': '51d5c276418edb53c0591d7d3aed29d34540f00103f901923a8c9601000000920314416e746c6572204b69746368656e202620426172'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.4305576, 43.64971700054068]}},
#   {'type': 'Feature',
#    'properties': {'name': "O'Somae",
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M4M 2H1',
#     'suburb': 'Toronto—Danforth',
#     'street': 'Broadview Avenue',
#     'housenumber': '357',
#     'lon': -79.3523815,
#     'lat': 43.6652718,
#     'state_code': 'ON',
#     'formatted': "O'Somae, 357 Broadview Avenue, Old Toronto, ON M4M 2H1, Canada",
#     'address_line1': "O'Somae",
#     'address_line2': '357 Broadview Avenue, Old Toronto, ON M4M 2H1, Canada',
#     'categories': ['catering', 'catering.restaurant', 'vegan', 'vegetarian'],
#     'details': ['details', 'details.catering', 'details.contact'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': "O'Somae",
#       'email': 'info@osomae.com',
#       'phone': '+1-416-461-1072',
#       'osm_id': 8847398274,
#       'amenity': 'restaurant',
#       'cuisine': 'brunch',
#       'website': 'https://osomae.com/',
#       'osm_type': 'n',
#       'addr:city': 'Toronto',
#       'diet:meat': 'yes',
#       'diet:vegan': 'yes',
#       'addr:street': 'Broadview Avenue',
#       'addr:postcode': 'M4M 2H1',
#       'addr:province': 'Ontario',
#       'opening_hours': 'Mo 10:00-17:00, We-Su 10:00-17:00',
#       'diet:vegetarian': 'yes',
#       'addr:housenumber': 357}},
#     'place_id': '51ca8d226b8dd653c059de2259a027d54540f00103f9018295580f020000009203074f27536f6d6165'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.3523815, 43.66527180054048]}},
#   {'type': 'Feature',
#    'properties': {'name': "Jack and Lil's",
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M6C 1A9',
#     'district': 'Hillcrest Village',
#     'suburb': "Toronto—St. Paul's",
#     'street': 'St. Clair Avenue West',
#     'housenumber': '684',
#     'lon': -79.4257348,
#     'lat': 43.6820522,
#     'state_code': 'ON',
#     'formatted': "Jack and Lil's, 684 St. Clair Avenue West, Old Toronto, ON M6C 1A9, Canada",
#     'address_line1': "Jack and Lil's",
#     'address_line2': '684 St. Clair Avenue West, Old Toronto, ON M6C 1A9, Canada',
#     'categories': ['catering',
#      'catering.restaurant',
#      'gluten_free',
#      'vegan',
#      'vegetarian'],
#     'details': ['details', 'details.catering', 'details.contact'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': "Jack and Lil's",
#       'phone': '+1 647-347-5459',
#       'osm_id': 8864588914,
#       'amenity': 'restaurant',
#       'website': 'http://www.jackandlils.com/',
#       'osm_type': 'n',
#       'addr:city': 'Toronto',
#       'diet:vegan': 'yes',
#       'addr:street': 'St. Clair Avenue West',
#       'addr:province': 'Ontario',
#       'opening_hours': 'We-Su 09:00-17:00',
#       'diet:dairy_free': 'yes',
#       'diet:vegetarian': 'yes',
#       'addr:housenumber': 684,
#       'diet:gluten_free': 'yes'}},
#     'place_id': '5139b12c3d3fdb53c0591cbe8b7c4dd74540f00103f90172e45e100200000092030e4a61636b20616e64204c696c2773'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.4257348, 43.682052200540255]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Yumei Sushi',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M4E 1G1',
#     'district': 'The Beaches',
#     'suburb': 'Beaches—East York',
#     'street': 'Queen Street East',
#     'housenumber': '2116',
#     'lon': -79.2950418,
#     'lat': 43.6712632,
#     'state_code': 'ON',
#     'formatted': 'Yumei Sushi, 2116 Queen Street East, Old Toronto, ON M4E 1G1, Canada',
#     'address_line1': 'Yumei Sushi',
#     'address_line2': '2116 Queen Street East, Old Toronto, ON M4E 1G1, Canada',
#     'categories': ['catering',
#      'catering.restaurant',
#      'catering.restaurant.japanese',
#      'catering.restaurant.sushi',
#      'vegetarian'],
#     'details': ['details',
#      'details.catering',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Yumei Sushi',
#       'phone': '+1 416-698-7705',
#       'osm_id': 9153374265,
#       'amenity': 'restaurant',
#       'cuisine': 'japanese;sushi',
#       'website': 'https://www.yumeisushi.ca/',
#       'osm_type': 'n',
#       'addr:city': 'Toronto',
#       'diet:meat': 'yes',
#       'addr:street': 'Queen Street East',
#       'reservation': 'yes',
#       'diet:seafood': 'yes',
#       'addr:postcode': 'M4E 1G1',
#       'addr:province': 'ON',
#       'opening_hours': 'Mo-Su 16:00-21:00',
#       'diet:vegetarian': 'yes',
#       'addr:housenumber': 2116,
#       'air_conditioning': 'yes'}},
#     'place_id': '51fe7c00f7e1d253c05928aadaf3ebd54540f00103f901396895210200000092030b59756d6569205375736869'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.2950418, 43.67126320054041]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Shawarma Royale',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Toronto',
#     'postcode': 'M9B 1B1',
#     'district': 'Cloverdale',
#     'suburb': 'Etobicoke',
#     'quarter': 'Etobicoke—Lakeshore',
#     'street': 'Dundas Street West',
#     'housenumber': '5415',
#     'lon': -79.5417898,
#     'lat': 43.6338472,
#     'state_code': 'ON',
#     'formatted': 'Shawarma Royale, 5415 Dundas Street West, Toronto, ON M9B 1B1, Canada',
#     'address_line1': 'Shawarma Royale',
#     'address_line2': '5415 Dundas Street West, Toronto, ON M9B 1B1, Canada',
#     'categories': ['catering', 'catering.restaurant', 'halal', 'vegetarian'],
#     'details': ['details', 'details.catering', 'details.contact'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Shawarma Royale',
#       'phone': '+1-416-239-0001',
#       'osm_id': 9339116358,
#       'amenity': 'restaurant',
#       'cuisine': 'middle_eastern;shawarma',
#       'website': 'https://www.shawarmaroyale.com/',
#       'osm_type': 'n',
#       'addr:unit': 'B',
#       'diet:halal': 'yes',
#       'addr:street': 'Dundas Street West',
#       'addr:postcode': 'M9B 1B1',
#       'opening_hours': 'Mo-Su 11:00-23:00',
#       'diet:vegetarian': 'yes',
#       'addr:housenumber': 5415}},
#     'place_id': '519c1320aface253c059fd7db2e721d14540f00103f901469ba72c0200000092030f5368617761726d6120526f79616c65'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.5417898, 43.63384720054089]}},
#   {'type': 'Feature',
#    'properties': {'name': 'LOV',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M5V 1M6',
#     'district': 'King West',
#     'suburb': 'Spadina—Fort York',
#     'street': 'King Street West',
#     'housenumber': '620',
#     'lon': -79.4008714,
#     'lat': 43.6447555,
#     'state_code': 'ON',
#     'formatted': 'LOV, 620 King Street West, Old Toronto, ON M5V 1M6, Canada',
#     'address_line1': 'LOV',
#     'address_line2': '620 King Street West, Old Toronto, ON M5V 1M6, Canada',
#     'categories': ['catering',
#      'catering.restaurant',
#      'vegan',
#      'vegan.only',
#      'vegetarian',
#      'vegetarian.only'],
#     'details': ['details', 'details.catering', 'details.contact'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'LOV',
#       'phone': '+1 416 3668568',
#       'osm_id': 9579220217,
#       'amenity': 'restaurant',
#       'website': 'https://lov.com/en/restaurants/lov-kingwest-toronto/',
#       'osm_type': 'n',
#       'addr:city': 'Toronto',
#       'addr:unit': 102,
#       'diet:vegan': 'only',
#       'addr:street': 'King Street West',
#       'addr:postcode': 'M5V 1M6',
#       'addr:province': 'ON',
#       'opening_hours': 'Mo-We 17:00-22:00,Th 12:00-22:00,Fr 12:00-23:00,Sa 10:00-22:00,Su 10:00-21:00',
#       'diet:vegetarian': 'only',
#       'addr:housenumber': 620}},
#     'place_id': '51b53984e0a7d953c0598c5e265987d24540f00103f901f94cf73a020000009203034c4f56'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.40087139999999, 43.644755500540754]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Fresh on Bloor',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M5S 1W5',
#     'district': 'The Annex',
#     'suburb': 'University—Rosedale',
#     'street': 'Bloor Street West',
#     'housenumber': '326',
#     'lon': -79.40352098058442,
#     'lat': 43.6669852,
#     'state_code': 'ON',
#     'formatted': 'Fresh on Bloor, 326 Bloor Street West, Old Toronto, ON M5S 1W5, Canada',
#     'address_line1': 'Fresh on Bloor',
#     'address_line2': '326 Bloor Street West, Old Toronto, ON M5S 1W5, Canada',
#     'categories': ['catering',
#      'catering.restaurant',
#      'vegan',
#      'vegetarian',
#      'vegetarian.only',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details', 'details.catering', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Fresh on Bloor',
#       'osm_id': 536134367,
#       'amenity': 'restaurant',
#       'website': 'https://freshrestaurants.ca/',
#       'osm_type': 'w',
#       'takeaway': 'yes',
#       'addr:city': 'Toronto',
#       'diet:vegan': 'yes',
#       'wheelchair': 'yes',
#       'addr:street': 'Bloor Street West',
#       'opening_hours': 'Mo-Fr 11:30-22:00; Sa-Su 10:30-22:00',
#       'diet:vegetarian': 'only',
#       'addr:housenumber': 326}},
#     'place_id': '516dc486efd2d953c059175f0c605ed54540f00102f901dfc2f41f0000000092030e4672657368206f6e20426c6f6f72'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.40349949036472, 43.66694260219645]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Naan Spot',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M5T 1S5',
#     'district': 'Kensington Market',
#     'suburb': 'University—Rosedale',
#     'street': 'College Street',
#     'housenumber': '310',
#     'lon': -79.4022122,
#     'lat': 43.6577184,
#     'state_code': 'ON',
#     'formatted': 'Naan Spot, 310 College Street, Old Toronto, ON M5T 1S5, Canada',
#     'address_line1': 'Naan Spot',
#     'address_line2': '310 College Street, Old Toronto, ON M5T 1S5, Canada',
#     'categories': ['catering', 'catering.restaurant', 'vegan', 'vegetarian'],
#     'details': ['details',
#      'details.catering',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Naan Spot',
#       'phone': '+1-647-343-6226',
#       'osm_id': 2806099852,
#       'amenity': 'restaurant',
#       'delivery': 'yes',
#       'osm_type': 'n',
#       'addr:city': 'Toronto',
#       'diet:meat': 'yes',
#       'diet:vegan': 'yes',
#       'addr:street': 'College Street',
#       'opening_hours': 'Mo-Su 11:30-22:30',
#       'diet:vegetarian': 'yes',
#       'addr:housenumber': 310}},
#     'place_id': '5157433dd8bdd953c0594d26d61d30d44540f00103f9018caf41a7000000009203094e61616e2053706f74'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.4022122, 43.65771840054058]}},
#   {'type': 'Feature',
#    'properties': {'name': "King's Café",
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M5T 1M1',
#     'district': 'Kensington Market',
#     'suburb': 'University—Rosedale',
#     'street': 'Augusta Avenue',
#     'housenumber': '192',
#     'lon': -79.4021709,
#     'lat': 43.6543703,
#     'state_code': 'ON',
#     'formatted': "King's Café, 192 Augusta Avenue, Old Toronto, ON M5T 1M1, Canada",
#     'address_line1': "King's Café",
#     'address_line2': '192 Augusta Avenue, Old Toronto, ON M5T 1M1, Canada',
#     'categories': ['catering',
#      'catering.restaurant',
#      'vegetarian',
#      'vegetarian.only',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.catering',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': "King's Café",
#       'phone': '+1-416-591-1340',
#       'osm_id': 5051870621,
#       'amenity': 'restaurant',
#       'website': 'http://www.kingscafe.com/',
#       'osm_type': 'n',
#       'addr:city': 'Toronto',
#       'wheelchair': 'yes',
#       'addr:street': 'Augusta Avenue',
#       'diet:vegetarian': 'only',
#       'addr:housenumber': 192}},
#     'place_id': '51cab9032bbdd953c059d925f067c2d34540f00103f9019d6d1d2d0100000092030c4b696e67277320436166c3a9'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.40217090000002, 43.65437030054063]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Oxtail Pho - Banh Mi & Vegetarian',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M6J 1V3',
#     'district': 'Bellwoods',
#     'suburb': 'University—Rosedale',
#     'street': 'Dundas Street West',
#     'housenumber': '814',
#     'lon': -79.4089645,
#     'lat': 43.6518402,
#     'state_code': 'ON',
#     'formatted': 'Oxtail Pho - Banh Mi & Vegetarian, 814 Dundas Street West, Old Toronto, ON M6J 1V3, Canada',
#     'address_line1': 'Oxtail Pho - Banh Mi & Vegetarian',
#     'address_line2': '814 Dundas Street West, Old Toronto, ON M6J 1V3, Canada',
#     'categories': ['catering', 'catering.restaurant', 'vegetarian'],
#     'details': ['details',
#      'details.catering',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Oxtail Pho - Banh Mi & Vegetarian',
#       'phone': '+1-416-537-0188',
#       'osm_id': 5723638621,
#       'amenity': 'restaurant',
#       'website': 'https://www.oxtail-pho.com/',
#       'osm_type': 'n',
#       'addr:city': 'Toronto',
#       'wheelchair': 'no',
#       'addr:street': 'Dundas Street West',
#       'addr:postcode': 'M6J 1V3',
#       'diet:vegetarian': 'yes',
#       'addr:housenumber': 814}},
#     'place_id': '51652e70792cda53c05926c5eb7f6fd34540f00103f9015dcb2755010000009203214f787461696c2050686f202d2042616e68204d692026205665676574617269616e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.40896449999998, 43.65184020054066]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Kyouka Ramen',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M4E 1E9',
#     'district': 'The Beaches',
#     'suburb': 'Beaches—East York',
#     'street': 'Queen Street East',
#     'housenumber': '2222',
#     'lon': -79.2882364,
#     'lat': 43.6726491,
#     'state_code': 'ON',
#     'formatted': 'Kyouka Ramen, 2222 Queen Street East, Old Toronto, ON M4E 1E9, Canada',
#     'address_line1': 'Kyouka Ramen',
#     'address_line2': '2222 Queen Street East, Old Toronto, ON M4E 1E9, Canada',
#     'categories': ['catering',
#      'catering.restaurant',
#      'catering.restaurant.japanese',
#      'catering.restaurant.ramen',
#      'vegetarian'],
#     'details': ['details', 'details.catering', 'details.contact'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Kyouka Ramen',
#       'phone': '+1 6477486288',
#       'osm_id': 9153350672,
#       'amenity': 'restaurant',
#       'cuisine': 'ramen;japanese',
#       'website': 'https://kyouka.ca/',
#       'osm_type': 'n',
#       'addr:city': 'Toronto',
#       'diet:meat': 'yes',
#       'addr:street': 'Queen Street East',
#       'addr:postcode': 'M4E 1E9',
#       'addr:province': 'Ontario',
#       'diet:vegetarian': 'yes',
#       'addr:housenumber': 2222}},
#     'place_id': '5112e1157772d253c0599d40a05d19d64540f00103f901100c95210200000092030c4b796f756b612052616d656e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.28823639999999, 43.67264910054039]}},
#   {'type': 'Feature',
#    'properties': {'name': 'desimane',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Toronto',
#     'postcode': 'M1S 1V3',
#     'suburb': 'Scarborough',
#     'quarter': 'Scarborough North',
#     'street': 'Sheppard Avenue East',
#     'housenumber': '4445',
#     'lon': -79.2670827,
#     'lat': 43.7874641,
#     'state_code': 'ON',
#     'formatted': 'desimane, 4445 Sheppard Avenue East, Toronto, ON M1S 1V3, Canada',
#     'address_line1': 'desimane',
#     'address_line2': '4445 Sheppard Avenue East, Toronto, ON M1S 1V3, Canada',
#     'categories': ['catering',
#      'catering.restaurant',
#      'catering.restaurant.indian',
#      'vegetarian'],
#     'details': ['details', 'details.catering', 'details.contact'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'desimane',
#       'phone': '+1 416-854-2626',
#       'osm_id': 9349817778,
#       'amenity': 'restaurant',
#       'cuisine': 'indian',
#       'website': 'http://www.desimanesangeetha.ca/',
#       'osm_type': 'n',
#       'addr:city': 'Scarborough',
#       'addr:street': 'Sheppard Avenue East',
#       'addr:postcode': 'M1S 1V3',
#       'addr:province': 'ON',
#       'diet:vegetarian': 'yes',
#       'addr:housenumber': 4445}},
#     'place_id': '51f47409e217d153c059154ba79fcbe44540f00103f901b2e54a2d02000000920308646573696d616e65'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.2670827, 43.78746410053842]}},
#   {'type': 'Feature',
#    'properties': {'name': 'The Greek Grill',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Toronto',
#     'postcode': 'M4J 3S1',
#     'district': 'East York',
#     'neighbourhood': 'Todmorden Village',
#     'suburb': 'East York',
#     'quarter': 'Toronto—Danforth',
#     'street': "O'Connor Drive",
#     'lon': -79.3500867,
#     'lat': 43.6935209,
#     'state_code': 'ON',
#     'formatted': "The Greek Grill, O'Connor Drive, Toronto, ON M4J 3S1, Canada",
#     'address_line1': 'The Greek Grill',
#     'address_line2': "O'Connor Drive, Toronto, ON M4J 3S1, Canada",
#     'categories': ['catering', 'catering.restaurant', 'vegetarian'],
#     'details': ['details', 'details.catering'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'The Greek Grill',
#       'osm_id': 387789998,
#       'amenity': 'restaurant',
#       'osm_type': 'n',
#       'diet:vegan': 'no',
#       'opening_hours': 'Mo-Su 11:00-22:00',
#       'diet:vegetarian': 'yes',
#       'check_date:opening_hours': '2020-10-12'}},
#     'place_id': '51eed00bd267d653c059c174f94ac5d84540f00103f901ae341d170000000092030f54686520477265656b204772696c6c'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.35008669999999, 43.693520900540086]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Greens Vegetarian Restaurant',
#     'country': 'Canada',
#     'country_code': 'ca',
#     'state': 'Ontario',
#     'county': 'Golden Horseshoe',
#     'city': 'Old Toronto',
#     'postcode': 'M5T 1H5',
#     'district': 'Kensington Market',
#     'suburb': 'University—Rosedale',
#     'street': 'Dundas Street West',
#     'lon': -79.4024581,
#     'lat': 43.6521175,
#     'state_code': 'ON',
#     'formatted': 'Greens Vegetarian Restaurant, Dundas Street West, Old Toronto, ON M5T 1H5, Canada',
#     'address_line1': 'Greens Vegetarian Restaurant',
#     'address_line2': 'Dundas Street West, Old Toronto, ON M5T 1H5, Canada',
#     'categories': ['catering',
#      'catering.restaurant',
#      'catering.restaurant.chinese',
#      'vegetarian',
#      'vegetarian.only'],
#     'details': ['details.catering', 'details.contact'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Greens Vegetarian Restaurant',
#       'phone': '+1-416-603-3337',
#       'osm_id': 2796392969,
#       'amenity': 'restaurant',
#       'cuisine': 'chinese',
#       'osm_type': 'n',
#       'diet:vegetarian': 'only'}},
#     'place_id': '51a9609edfc1d953c05958fc149678d34540f00103f9010992ada60000000092031c477265656e73205665676574617269616e2052657374617572616e74'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.4024581, 43.65211750054067]}}]}

# %%
places_data.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
len(places_data['features'])
# Out:
# 20

# %%
# Set the geographical coordinates for Sydney, Australia
latitude = -33.8698439
longitude = 151.2082848

# Set the parameters for the type of place
categories = "catering.restaurant"
conditions = "vegetarian"
radius = 8000

# Set the parameters for the type of search
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    "conditions":conditions,
    "limit":limit,
    "filter":filters,
    "bias":bias,
    "apiKey":geoapify_key    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
print(response.url)
# Out:
# https://api.geoapify.com/v2/places?categories=catering.restaurant&conditions=vegetarian&limit=20&filter=circle%3A151.2082848%2C-33.8698439%2C8000&bias=proximity%3A151.2082848%2C-33.8698439&apiKey=7757f89767bc454db74be2b640389f77

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2080336,
#                     -33.87648089966814
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Macchiato",
#                 "address_line2": "338 Pitt Street, Sydney NSW 2000, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.pizza",
#                     "vegetarian",
#                     "wheelchair",
#                     "wheelchair.limited"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "cuisine": "pizza",
#                         "diet:vegan": "no",
#                         "diet:vegetarian": "yes",
#                         "name": "Macchiato",
#                         "opening_hours:signed": "no",
#                         "osm_id": 4021091492,
#                         "osm_type": "n",
#                         "wheelchair": "limited"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 737,
#                 "district": "Koreatown",
#                 "formatted": "Macchiato, 338 Pitt Street, Sydney NSW 2000, Australia",
#                 "housenumber": "338",
#                 "lat": -33.8764809,
#                 "lon": 151.2080336,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Macchiato",
#                 "place_id": "51038f1436a8e662405958d2af8630f040c0f00103f901a4fcacef000000009203094d616363686961746f",
#                 "postcode": "2000",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Pitt Street",
#                 "suburb": "Sydney"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2043797,
#                     -33.87599289966807
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Sushi Rio",
#                 "address_line2": "Liverpool Street, Sydney NSW 2000, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "vegan",
#                     "vegetarian"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "name": "Sushi Rio",
#                         "opening_hours": "Su-Th 12:00-21:00; Fr,Sa 12:00-22:00",
#                         "osm_id": 4021093289,
#                         "osm_type": "n",
#                         "outdoor_seating": "no",
#                         "smoking": "no"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 772,
#                 "district": "Chinatown",
#                 "formatted": "Sushi Rio, Liverpool Street, Sydney NSW 2000, Australia",
#                 "lat": -33.8759929,
#                 "lon": 151.2043797,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Sushi Rio",
#                 "place_id": "51ecee4b478ae662405921cd0b8920f040c0f00103f901a903adef0000000092030953757368692052696f",
#                 "postcode": "2000",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Liverpool Street",
#                 "suburb": "Sydney"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2024953,
#                     -33.87804939966843
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Hakatamon Ramen",
#                 "address_line2": "Nicolle Walk, Haymarket NSW 2000, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.japanese",
#                     "catering.restaurant.ramen",
#                     "vegetarian"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "contact:facebook": "hakatamondarlingsquare",
#                         "cuisine": "japanese;ramen",
#                         "diet:vegetarian": "yes",
#                         "name": "Hakatamon Ramen",
#                         "opening_hours:signed": "no",
#                         "osm_id": 9480685417,
#                         "osm_type": "n",
#                         "outdoor_seating": "yes",
#                         "smoking": "no",
#                         "survey:date": "2022-02-05"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 1056,
#                 "district": "Darling Square",
#                 "formatted": "Hakatamon Ramen, Nicolle Walk, Haymarket NSW 2000, Australia",
#                 "lat": -33.8780494,
#                 "lon": 151.2024953,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Hakatamon Ramen",
#                 "place_id": "5100636cd77ae662405996ec37ec63f040c0f00103f90169c717350200000092030f48616b6174616d6f6e2052616d656e",
#                 "postcode": "2000",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Nicolle Walk",
#                 "suburb": "Haymarket"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.192878,
#                     -33.866840799666434
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Yuzu",
#                 "address_line2": "1 Scott Street, Pyrmont NSW 2009, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.japanese",
#                     "vegan",
#                     "vegetarian",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "cuisine": "japanese",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "name": "Yuzu",
#                         "opening_hours": "Mo-Fr 11:30-09:30, Sa 05:30-09:30; Su off",
#                         "osm_id": 2874264581,
#                         "osm_type": "n",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 1464,
#                 "formatted": "Yuzu, 1 Scott Street, Pyrmont NSW 2009, Australia",
#                 "housenumber": "1",
#                 "lat": -33.8668408,
#                 "lon": 151.192878,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Yuzu",
#                 "place_id": "51c6c37b0e2ce6624059f2b3aaa3f4ee40c0f00103f90105cc51ab0000000092030459757a75",
#                 "postcode": "2009",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Scott Street",
#                 "suburb": "Pyrmont"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.19680200219764,
#                     -33.88054740172498
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Dumpling & Noodle House",
#                 "address_line2": "430 Wattle Street, Ultimo NSW 2007, Australia",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.residential",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.dumpling",
#                     "vegan",
#                     "vegetarian"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 430,
#                         "addr:postcode": 2007,
#                         "addr:state": "NSW",
#                         "addr:street": "Wattle Street",
#                         "addr:suburb": "Ultimo",
#                         "amenity": "restaurant",
#                         "building": "house",
#                         "building:levels": 2,
#                         "cuisine": "chinese;dumplings;noodle",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "name": "Dumpling & Noodle House",
#                         "opening_hours": "PH,Mo-Su 10:00-22:00",
#                         "osm_id": 1047327174,
#                         "osm_type": "w",
#                         "outdoor_seating": "yes",
#                         "smoking": "no",
#                         "wheelchair": "no"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 1583,
#                 "formatted": "Dumpling & Noodle House, 430 Wattle Street, Ultimo NSW 2007, Australia",
#                 "housenumber": "430",
#                 "lat": -33.88054715,
#                 "lon": 151.19680242896868,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Dumpling & Noodle House",
#                 "place_id": "513d67b6334ce6624059487efac6b5f040c0f00102f901c6f16c3e0000000092031744756d706c696e672026204e6f6f646c6520486f757365",
#                 "postcode": "2007",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Wattle Street",
#                 "suburb": "Ultimo"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2138725,
#                     -33.88675009966996
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Nour",
#                 "address_line2": "490 Crown Street, Surry Hills NSW 2010, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.arab",
#                     "catering.restaurant.lebanese",
#                     "vegetarian"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 490,
#                         "addr:postcode": 2010,
#                         "addr:state": "NSW",
#                         "addr:street": "Crown Street",
#                         "addr:suburb": "Surry Hills",
#                         "addr:unit": "Shop 3",
#                         "amenity": "restaurant",
#                         "cuisine": "arab;lebanese",
#                         "diet:meat": "yes",
#                         "diet:vegetarian": "yes",
#                         "name": "Nour",
#                         "opening_hours": "Tu-Sa 18:00-22:00, Fr-Sa 12:00-14:30, Su 10:00-14:30",
#                         "osm_id": 8109734733,
#                         "osm_type": "n",
#                         "phone": "+61 2 9331 3413",
#                         "reservation": "recommended",
#                         "website": "https://noursydney.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact"
#                 ],
#                 "distance": 1945,
#                 "district": "Strawberry Hills",
#                 "formatted": "Nour, 490 Crown Street, Surry Hills NSW 2010, Australia",
#                 "housenumber": "490",
#                 "lat": -33.8867501,
#                 "lon": 151.2138725,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Nour",
#                 "place_id": "517120240bd8e662405953e7fa0681f140c0f00103f9014dbb60e3010000009203044e6f7572",
#                 "postcode": "2010",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Crown Street",
#                 "suburb": "Surry Hills"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2104967,
#                     -33.84378949966237
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "ANCHOR Cafe & Restaurant",
#                 "address_line2": "118 Alfred Street South, Milsons Point NSW 2061, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "gluten_free",
#                     "internet_access",
#                     "vegan",
#                     "vegetarian",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 118,
#                         "addr:postcode": 2061,
#                         "addr:state": "NSW",
#                         "addr:street": "Alfred Street South",
#                         "addr:suburb": "Milsons Point",
#                         "amenity": "restaurant",
#                         "cuisine": "pizza;italian;coffee_shop;ice_cream;seafood",
#                         "delivery": "yes",
#                         "diet:gluten_free": "yes",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "email": "info@anchorrestaurant.com.au",
#                         "internet_access": "wlan",
#                         "name": "ANCHOR Cafe & Restaurant",
#                         "opening_hours": "Mo-Su 17:00-21:30",
#                         "osm_id": 6332613852,
#                         "osm_type": "n",
#                         "outdoor_seating": "yes",
#                         "phone": "+61299222996",
#                         "website": "https://anchorrestaurant.com.au/",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "distance": 2897,
#                 "district": "Lower North Shore",
#                 "formatted": "ANCHOR Cafe & Restaurant, 118 Alfred Street South, Milsons Point NSW 2061, Australia",
#                 "housenumber": "118",
#                 "lat": -33.8437895,
#                 "lon": 151.2104967,
#                 "municipality": "North Sydney Council",
#                 "name": "ANCHOR Cafe & Restaurant",
#                 "place_id": "514f4d9363bce662405909e1584b01ec40c0f00103f901dc04747901000000920318414e43484f52204361666520262052657374617572616e74",
#                 "postcode": "2061",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Alfred Street South",
#                 "suburb": "Milsons Point"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.1860361,
#                     -33.89280459967104
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Calle Rey",
#                 "address_line2": "62-64 King Street, Newtown NSW 2042, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.mexican",
#                     "vegan",
#                     "vegan.only",
#                     "vegetarian",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": "62-64",
#                         "addr:postcode": 2042,
#                         "addr:state": "NSW",
#                         "addr:street": "King Street",
#                         "addr:suburb": "Newtown",
#                         "amenity": "restaurant",
#                         "changing_table": "no",
#                         "cuisine": "mexican",
#                         "diet:vegan": "only",
#                         "diet:vegetarian": "yes",
#                         "name": "Calle Rey",
#                         "opening_hours": "Tu-Sa 05:00-21:00",
#                         "osm_id": 7728132792,
#                         "osm_type": "n",
#                         "phone": "+61 475 587 074",
#                         "reservation": "yes",
#                         "smoking": "no",
#                         "takeaway": "yes",
#                         "toilets": "yes",
#                         "toilets:access": "customers",
#                         "toilets:wheelchair": "no",
#                         "website": "http://shareplantbased.com/",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "distance": 3275,
#                 "district": "Inner West",
#                 "formatted": "Calle Rey, 62-64 King Street, Newtown NSW 2042, Australia",
#                 "housenumber": "62-64",
#                 "lat": -33.8928046,
#                 "lon": 151.1860361,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Calle Rey",
#                 "place_id": "5103acfa01f4e56240591aa7ce6b47f240c0f00103f901b8f2a1cc0100000092030943616c6c6520526579",
#                 "postcode": "2042",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "King Street",
#                 "suburb": "Newtown"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.20221629999998,
#                     -33.827129299659425
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Montezuma's",
#                 "address_line2": "51 Alexander Street, Crows Nest NSW 2065, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.mexican",
#                     "gluten_free",
#                     "vegetarian"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 51,
#                         "addr:postcode": 2065,
#                         "addr:state": "NSW",
#                         "addr:street": "Alexander Street",
#                         "addr:suburb": "Crows Nest",
#                         "amenity": "restaurant",
#                         "contact:facebook": "https://www.facebook.com/montezumasmexican/",
#                         "cuisine": "mexican",
#                         "delivery": "yes",
#                         "diet:gluten_free": "yes",
#                         "diet:vegetarian": "yes",
#                         "name": "Montezuma's",
#                         "osm_id": 6836160011,
#                         "osm_type": "n",
#                         "outdoor_seating": "yes",
#                         "phone": "+61 2 9901 3533",
#                         "start_date": 1978,
#                         "takeaway": "yes",
#                         "website": "https://www.montezumascrowsnest.com.au"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "distance": 4771,
#                 "district": "Lower North Shore",
#                 "formatted": "Montezuma's, 51 Alexander Street, Crows Nest NSW 2065, Australia",
#                 "housenumber": "51",
#                 "lat": -33.8271293,
#                 "lon": 151.2022163,
#                 "municipality": "North Sydney Council",
#                 "name": "Montezuma's",
#                 "neighbourhood": "Crows Nest Junction",
#                 "place_id": "51fa66518e78e6624059e1cc755fdfe940c0f00103f9010b8677970100000092030b4d6f6e74657a756d612773",
#                 "postcode": "2065",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Alexander Street",
#                 "suburb": "Crows Nest"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.1620293,
#                     -33.90974279967406
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Pizza Madre",
#                 "address_line2": "Sydenham Road, Marrickville NSW 2204, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.pizza",
#                     "vegetarian",
#                     "vegetarian.only"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "cuisine": "pizza",
#                         "diet:vegetarian": "only",
#                         "name": "Pizza Madre",
#                         "osm_id": 5708242227,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.catering"
#                 ],
#                 "distance": 6156,
#                 "district": "Inner West",
#                 "formatted": "Pizza Madre, Sydenham Road, Marrickville NSW 2204, Australia",
#                 "lat": -33.9097428,
#                 "lon": 151.1620293,
#                 "municipality": "Inner West Council",
#                 "name": "Pizza Madre",
#                 "place_id": "51cd0f12582fe5624059902fba7372f440c0f00103f90133dd3c540100000092030b50697a7a61204d61647265",
#                 "postcode": "2204",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Sydenham Road",
#                 "suburb": "Marrickville"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.27314279999996,
#                     -33.8908834996707
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Cali Press",
#                 "address_line2": "2/16 Hall Street, Bondi Beach NSW 2026, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "vegetarian"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": "2/16",
#                         "addr:postcode": 2026,
#                         "addr:state": "NSW",
#                         "addr:street": "Hall Street",
#                         "amenity": "restaurant",
#                         "cuisine": "breakfast;tea;coffee_shop",
#                         "diet:vegetarian": "yes",
#                         "name": "Cali Press",
#                         "osm_id": 1198026262,
#                         "osm_type": "n",
#                         "outdoor_seating": "yes",
#                         "website": "https://calipress.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 6438,
#                 "district": "Eastern Suburbs",
#                 "formatted": "Cali Press, 2/16 Hall Street, Bondi Beach NSW 2026, Australia",
#                 "housenumber": "2/16",
#                 "lat": -33.8908835,
#                 "lon": 151.2731428,
#                 "municipality": "Waverley Council",
#                 "name": "Cali Press",
#                 "neighbourhood": "Six Ways",
#                 "place_id": "516824f895bde8624059dbd0737808f240c0f00103f901166e68470000000092030a43616c69205072657373",
#                 "postcode": "2026",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Hall Street",
#                 "suburb": "Bondi Beach"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.17981829999997,
#                     -33.93241109967814
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Bar Roma",
#                 "address_line2": "Shiers Avenue, Mascot NSW 2020, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "vegetarian",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "Bayside Council",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "check_date:opening_hours": "2022-07-22",
#                         "diet:vegan": "no",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "level": 1,
#                         "name": "Bar Roma",
#                         "opening_hours:signed": "no",
#                         "osm_id": 9903323456,
#                         "osm_type": "n",
#                         "outdoor_seating": "no",
#                         "payment:credit_cards": "yes",
#                         "payment:debit_cards": "yes",
#                         "smoking": "no",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.catering",
#                     "details.facilities",
#                     "details.payment"
#                 ],
#                 "distance": 7423,
#                 "formatted": "Bar Roma, Shiers Avenue, Mascot NSW 2020, Australia",
#                 "lat": -33.9324111,
#                 "lon": 151.1798183,
#                 "name": "Bar Roma",
#                 "place_id": "511cb74e12c1e5624059c3c5353f59f740c0f00103f90140b9484e0200000092030842617220526f6d61",
#                 "postcode": "2020",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Shiers Avenue",
#                 "suburb": "Mascot"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.1772724,
#                     -33.93170949967801
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Bar Corretto",
#                 "address_line2": "Shiers Avenue, Mascot NSW 2020, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "vegetarian",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "Bayside Council",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "check_date:opening_hours": "2022-07-22",
#                         "diet:vegan": "no",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "level": 1,
#                         "name": "Bar Corretto",
#                         "opening_hours:signed": "no",
#                         "osm_id": 9903332410,
#                         "osm_type": "n",
#                         "outdoor_seating": "no",
#                         "payment:credit_cards": "yes",
#                         "payment:debit_cards": "yes",
#                         "smoking": "no",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.catering",
#                     "details.facilities",
#                     "details.payment"
#                 ],
#                 "distance": 7438,
#                 "formatted": "Bar Corretto, Shiers Avenue, Mascot NSW 2020, Australia",
#                 "lat": -33.9317095,
#                 "lon": 151.1772724,
#                 "name": "Bar Corretto",
#                 "place_id": "51780f2b37ace5624059aa3ec34142f740c0f00103f9013adc484e0200000092030c42617220436f72726574746f",
#                 "postcode": "2020",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Shiers Avenue",
#                 "suburb": "Mascot"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.17806459999997,
#                     -33.93242959967813
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Wok on Air",
#                 "address_line2": "Shiers Avenue, Mascot NSW 2020, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "vegan",
#                     "vegetarian",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "Bayside Council",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "check_date:opening_hours": "2022-07-22",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "level": 1,
#                         "name": "Wok on Air",
#                         "opening_hours:signed": "no",
#                         "osm_id": 9821921615,
#                         "osm_type": "n",
#                         "outdoor_seating": "no",
#                         "payment:credit_cards": "yes",
#                         "payment:debit_cards": "yes",
#                         "smoking": "no",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.catering",
#                     "details.facilities",
#                     "details.payment"
#                 ],
#                 "distance": 7484,
#                 "formatted": "Wok on Air, Shiers Avenue, Mascot NSW 2020, Australia",
#                 "lat": -33.9324296,
#                 "lon": 151.1780646,
#                 "name": "Wok on Air",
#                 "place_id": "51683288b4b2e5624059503866da59f740c0f00103f9014fa16e490200000092030a576f6b206f6e20416972",
#                 "postcode": "2020",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Shiers Avenue",
#                 "suburb": "Mascot"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.1798858,
#                     -33.93464609967853
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Beer Deluxe",
#                 "address_line2": "Keith Smith Avenue, Mascot NSW 2020, Australia",
#                 "categories": [
#                     "catering",
#                     "catering.restaurant",
#                     "vegetarian"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "Bayside Council",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "check_date:opening_hours": "2022-10-31",
#                         "diet:vegetarian": "yes",
#                         "indoor_seating": "yes",
#                         "level": 1,
#                         "name": "Beer Deluxe",
#                         "opening_hours:signed": "no",
#                         "osm_id": 9574219830,
#                         "osm_type": "n",
#                         "outdoor_seating": "no",
#                         "smoking": "no"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.catering",
#                     "details.facilities"
#                 ],
#                 "distance": 7653,
#                 "formatted": "Beer Deluxe, Keith Smith Avenue, Mascot NSW 2020, Australia",
#                 "lat": -33.9346461,
#                 "lon": 151.1798858,
#                 "name": "Beer Deluxe",
#                 "place_id": "517980dd9fc1e562405904babf7ba2f740c0f00103f9013600ab3a0200000092030b426565722044656c757865",
#                 "postcode": "2020",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Keith Smith Avenue",
#                 "suburb": "Mascot"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %%
# Print the name and address of the first restaurant that appears
print(places_data["features"][0]["properties"]["name"])
print(places_data["features"][0]["properties"]["address_line2"])
# Out:
# Macchiato
# 338 Pitt Street, Sydney NSW 2000, Australia
