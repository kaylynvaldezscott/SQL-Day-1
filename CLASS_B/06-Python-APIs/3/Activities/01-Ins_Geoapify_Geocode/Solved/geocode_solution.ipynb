# %% [markdown]
# # Geoapify Geocode Demo

# %%
# Dependencies
import requests
import json

# Import the API key
from config import geoapify_key

# %%
geoapify_key
# Out:
# '4a987a25d5c0407a8b6de8933da491dc'

# %%
# Target city
target_city='Sydney, Australia'

# %%
# Target city
target_city = "Sydney, Australia"

# Build the endpoint URL
target_url = f"https://api.geoapify.com/v1/geocode/search?text={target_city}&format=json&apiKey={geoapify_key}"

# %%
import requests

url = "https://api.geoapify.com/v1/geocode/search?text=Sydney%2C%20Australia&lang=en&limit=20&type=city&format=json&apiKey=4a987a25d5c0407a8b6de8933da491dc"
          
response = requests.get(url)
#print(response.json())

# %%
# Build the endpoint URL
target_url = f"https://api.geoapify.com/v1/geocode/search?text={target_city}&format=json&apiKey={geoapify_key}"

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
geo_data=response.json()

# %%
base_url='https://api.geoapify.com/v1/geocode/search?'

# %%
# set up a parameters dictionary
params = {
    "text":target_city,
    "limit":'20',
    "apiKey":geoapify_key    
}

# %%
data=requests.get(base_url, params=params).json()
data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright'},
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Council of the City of Sydney',
#     'lon': 151.2082848,
#     'lat': -33.8698439,
#     'state_code': 'NSW',
#     'formatted': 'Sydney, NSW, Australia',
#     'address_line1': 'Sydney',
#     'address_line2': 'NSW, Australia',
#     'category': 'administrative',
#     'timezone': {'name': 'Australia/Sydney',
#      'offset_STD': '+10:00',
#      'offset_STD_seconds': 36000,
#      'offset_DST': '+11:00',
#      'offset_DST_seconds': 39600,
#      'abbreviation_STD': 'AEST',
#      'abbreviation_DST': 'AEDT'},
#     'plus_code': '4RRH46J5+38',
#     'plus_code_short': 'J5+38 Sydney, New South Wales, Australia',
#     'result_type': 'city',
#     'rank': {'importance': 0.9245908962989684,
#      'popularity': 7.332617625087506,
#      'confidence': 1,
#      'confidence_city_level': 1,
#      'match_type': 'full_match'},
#     'place_id': '512088e244aae662405903907f0b57ef40c0f00101f901f5bc570000000000c00208'},
#    'geometry': {'type': 'Point', 'coordinates': [151.2082848, -33.8698439]},
#    'bbox': [150.260825, -34.1732416, 151.343898, -33.3641864]},
#   {'type': 'Feature',
#    'properties': {'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright'},
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Council of the City of Sydney',
#     'postcode': '2000',
#     'suburb': 'Sydney',
#     'lon': 151.2101367482844,
#     'lat': -33.867926,
#     'state_code': 'NSW',
#     'formatted': 'Sydney, NSW, Australia',
#     'address_line1': 'Sydney',
#     'address_line2': 'NSW, Australia',
#     'category': 'administrative',
#     'timezone': {'name': 'Australia/Sydney',
#      'offset_STD': '+10:00',
#      'offset_STD_seconds': 36000,
#      'offset_DST': '+11:00',
#      'offset_DST_seconds': 39600,
#      'abbreviation_STD': 'AEST',
#      'abbreviation_DST': 'AEDT'},
#     'plus_code': '4RRH46J6+R3',
#     'plus_code_short': 'J6+R3 Sydney, New South Wales, Australia',
#     'result_type': 'suburb',
#     'rank': {'importance': 0.50001,
#      'popularity': 7.332617625087506,
#      'confidence': 1,
#      'confidence_city_level': 1,
#      'match_type': 'full_match'},
#     'place_id': '5138b2b370b9e66240598eacfc3218ef40c0f00101f901fe6c570000000000c00205'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.2101367482844, -33.867926]},
#    'bbox': [151.1970047, -33.8797755, 151.223011, -33.8561096]},
#   {'type': 'Feature',
#    'properties': {'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright'},
#     'name': 'Chinatown',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Council of the City of Sydney',
#     'postcode': '2000',
#     'suburb': 'Haymarket',
#     'quarter': 'Chinatown',
#     'lon': 151.204068,
#     'lat': -33.8783674,
#     'state_code': 'NSW',
#     'formatted': 'Chinatown, Haymarket NSW 2000, Australia',
#     'address_line1': 'Chinatown',
#     'address_line2': 'Haymarket NSW 2000, Australia',
#     'category': 'populated_place',
#     'timezone': {'name': 'Australia/Sydney',
#      'offset_STD': '+10:00',
#      'offset_STD_seconds': 36000,
#      'offset_DST': '+11:00',
#      'offset_DST_seconds': 39600,
#      'abbreviation_STD': 'AEST',
#      'abbreviation_DST': 'AEDT'},
#     'plus_code': '4RRH46C3+MJ',
#     'plus_code_short': 'C3+MJ Sydney, New South Wales, Australia',
#     'result_type': 'amenity',
#     'rank': {'importance': 0.5826503000284101,
#      'popularity': 7.060085625351875,
#      'confidence': 1,
#      'confidence_city_level': 1,
#      'match_type': 'inner_part'},
#     'place_id': '5120459db987e6624059b06fcc576ef040c0f00102f9012309e31900000000c002019203094368696e61746f776e'},
#    'geometry': {'type': 'Point', 'coordinates': [151.204068, -33.8783674]},
#    'bbox': [151.20339, -33.8794356, 151.2048011, -33.8775558]},
#   {'type': 'Feature',
#    'properties': {'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright'},
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Council of the City of Sydney',
#     'lon': 151.2050386296839,
#     'lat': -33.8890382,
#     'state_code': 'NSW',
#     'formatted': 'Council of the City of Sydney, NSW, Australia',
#     'address_line1': 'Council of the City of Sydney',
#     'address_line2': 'NSW, Australia',
#     'category': 'administrative',
#     'timezone': {'name': 'Australia/Sydney',
#      'offset_STD': '+10:00',
#      'offset_STD_seconds': 36000,
#      'offset_DST': '+11:00',
#      'offset_DST_seconds': 39600,
#      'abbreviation_STD': 'AEST',
#      'abbreviation_DST': 'AEDT'},
#     'plus_code': '4RRH4664+92',
#     'result_type': 'city',
#     'rank': {'importance': 0.6602672043141233,
#      'popularity': 6.340264879863925,
#      'confidence': 1,
#      'confidence_city_level': 1,
#      'match_type': 'full_match'},
#     'place_id': '51171d2cad8fe662405986f2f400ccf140c0f00101f901fa16130000000000c00208'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.2050386296839, -33.8890382]},
#    'bbox': [151.1748953, -33.9243832, 151.2330104, -33.8535496]}],
#  'query': {'text': 'Sydney, Australia',
#   'parsed': {'city': 'sydney',
#    'country': 'australia',
#    'expected_type': 'city'}}}

# %%
# Print the json (pretty printed)
#print(json.dumps(geo_data, indent=4, sort_keys=True))
from pprint import pprint
pprint(geo_data)
# Out:
# {'query': {'parsed': {'city': 'sydney',
#                       'country': 'australia',
#                       'expected_type': 'city'},
#            'text': 'Sydney, Australia'},
#  'results': [{'address_line1': 'Sydney',
#               'address_line2': 'NSW, Australia',
#               'bbox': {'lat1': -34.1732416,
#                        'lat2': -33.3641864,
#                        'lon1': 150.260825,
#                        'lon2': 151.343898},
#               'category': 'administrative',
#               'city': 'Sydney',
#               'country': 'Australia',
#               'country_code': 'au',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Sydney, NSW, Australia',
#               'lat': -33.8698439,
#               'lon': 151.2082848,
#               'municipality': 'Council of the City of Sydney',
#               'place_id': '512088e244aae662405903907f0b57ef40c0f00101f901f5bc570000000000c00208',
#               'plus_code': '4RRH46J5+38',
#               'plus_code_short': 'J5+38 Sydney, New South Wales, Australia',
#               'rank': {'confidence': 1,
#                        'confidence_city_level': 1,
#                        'importance': 0.9245908962989684,
#                        'match_type': 'full_match',
#                        'popularity': 7.332617625087506},
#               'result_type': 'city',
#               'state': 'New South Wales',
#               'state_code': 'NSW',
#               'timezone': {'abbreviation_DST': 'AEDT',
#                            'abbreviation_STD': 'AEST',
#                            'name': 'Australia/Sydney',
#                            'offset_DST': '+11:00',
#                            'offset_DST_seconds': 39600,
#                            'offset_STD': '+10:00',
#                            'offset_STD_seconds': 36000}},
#              {'address_line1': 'Sydney',
#               'address_line2': 'NSW, Australia',
#               'bbox': {'lat1': -33.8797755,
#                        'lat2': -33.8561096,
#                        'lon1': 151.1970047,
#                        'lon2': 151.223011},
#               'category': 'administrative',
#               'city': 'Sydney',
#               'country': 'Australia',
#               'country_code': 'au',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Sydney, NSW, Australia',
#               'lat': -33.867926,
#               'lon': 151.2101367482844,
#               'municipality': 'Council of the City of Sydney',
#               'place_id': '5138b2b370b9e66240598eacfc3218ef40c0f00101f901fe6c570000000000c00205',
#               'plus_code': '4RRH46J6+R3',
#               'plus_code_short': 'J6+R3 Sydney, New South Wales, Australia',
#               'postcode': '2000',
#               'rank': {'confidence': 1,
#                        'confidence_city_level': 1,
#                        'importance': 0.50001,
#                        'match_type': 'full_match',
#                        'popularity': 7.332617625087506},
#               'result_type': 'suburb',
#               'state': 'New South Wales',
#               'state_code': 'NSW',
#               'suburb': 'Sydney',
#               'timezone': {'abbreviation_DST': 'AEDT',
#                            'abbreviation_STD': 'AEST',
#                            'name': 'Australia/Sydney',
#                            'offset_DST': '+11:00',
#                            'offset_DST_seconds': 39600,
#                            'offset_STD': '+10:00',
#                            'offset_STD_seconds': 36000}},
#              {'address_line1': 'Chinatown',
#               'address_line2': 'Haymarket NSW 2000, Australia',
#               'bbox': {'lat1': -33.8794356,
#                        'lat2': -33.8775558,
#                        'lon1': 151.20339,
#                        'lon2': 151.2048011},
#               'category': 'populated_place',
#               'city': 'Sydney',
#               'country': 'Australia',
#               'country_code': 'au',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Chinatown, Haymarket NSW 2000, Australia',
#               'lat': -33.8783674,
#               'lon': 151.204068,
#               'municipality': 'Council of the City of Sydney',
#               'name': 'Chinatown',
#               'place_id': '5120459db987e6624059b06fcc576ef040c0f00102f9012309e31900000000c002019203094368696e61746f776e',
#               'plus_code': '4RRH46C3+MJ',
#               'plus_code_short': 'C3+MJ Sydney, New South Wales, Australia',
#               'postcode': '2000',
#               'quarter': 'Chinatown',
#               'rank': {'confidence': 1,
#                        'confidence_city_level': 1,
#                        'importance': 0.5826503000284101,
#                        'match_type': 'inner_part',
#                        'popularity': 7.060085625351875},
#               'result_type': 'amenity',
#               'state': 'New South Wales',
#               'state_code': 'NSW',
#               'suburb': 'Haymarket',
#               'timezone': {'abbreviation_DST': 'AEDT',
#                            'abbreviation_STD': 'AEST',
#                            'name': 'Australia/Sydney',
#                            'offset_DST': '+11:00',
#                            'offset_DST_seconds': 39600,
#                            'offset_STD': '+10:00',
#                            'offset_STD_seconds': 36000}},
#              {'address_line1': 'Council of the City of Sydney',
#               'address_line2': 'NSW, Australia',
#               'bbox': {'lat1': -33.9243832,
#                        'lat2': -33.8535496,
#                        'lon1': 151.1748953,
#                        'lon2': 151.2330104},
#               'category': 'administrative',
#               'city': 'Council of the City of Sydney',
#               'country': 'Australia',
#               'country_code': 'au',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Council of the City of Sydney, NSW, Australia',
#               'lat': -33.8890382,
#               'lon': 151.2050386296839,
#               'place_id': '51171d2cad8fe662405986f2f400ccf140c0f00101f901fa16130000000000c00208',
#               'plus_code': '4RRH4664+92',
#               'rank': {'confidence': 1,
#                        'confidence_city_level': 1,
#                        'importance': 0.6602672043141233,
#                        'match_type': 'full_match',
#                        'popularity': 6.340264879863925},
#               'result_type': 'city',
#               'state': 'New South Wales',
#               'state_code': 'NSW',
#               'timezone': {'abbreviation_DST': 'AEDT',
#                            'abbreviation_STD': 'AEST',
#                            'name': 'Australia/Sydney',
#                            'offset_DST': '+11:00',
#                            'offset_DST_seconds': 39600,
#                            'offset_STD': '+10:00',
#                            'offset_STD_seconds': 36000}}]}

# %%
# Extract latitude and longitude
lat = geo_data["results"][0]["lat"]
lon = geo_data["results"][0]["lon"]

# Print the latitude and longitude
print('''
    City: {0}
    Latitude: {1}
    Longitude: {2}
    '''.format(target_city, lat, lon))
# Out:
#     City: Sydney, Australia
#     Latitude: -33.8698439
#     Longitude: 151.2082848
