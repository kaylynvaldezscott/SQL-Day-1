# %%
# Dependencies
import requests
from config import api_key
import time

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Store a search term
query = "election"

# Search for articles published between a begin and end date
begin_date = "20160101"
end_date = "20160130"

# Build URL
urln=url+'api-key='+api_key+"&q="+query+"&begin_date="+begin_date +"&end_date="+end_date

# %%
urln
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=x80nwNZPylLJ5bOjkUACWrAcsTWAg8N5&q=election&begin_date=20160101&end_date=20160130'

# %%
requests.get(urln).json()['response']['docs']
# Out:
# [{'abstract': 'The Central African Republic’s constitutional court scrapped results from a legislative election, citing irregularities like illegible ballots and poor training for election workers.',
#   'web_url': 'https://www.nytimes.com/2016/01/26/world/africa/central-african-republic-court-invalidates-legislative-election.html',
#   'snippet': 'The Central African Republic’s constitutional court scrapped results from a legislative election, citing irregularities like illegible ballots and poor training for election workers.',
#   'lead_paragraph': 'The Central African Republic’s constitutional court certified presidential election results Monday but separately scrapped results from a legislative election, citing irregularities like illegible ballots and poor training for election workers. The court’s validation sets the stage for a runoff for the presidential election that pits Anicet-Georges Dologuélé against Faustin Archange Touadera, two former prime ministers. They will face each other in a vote scheduled for no sooner than Feb. 7. Election observers said that redoing the legislative vote, which took place simultaneously with the presidential vote, would be costly. Candidates were puzzled by the court’s decision. “This is illogical,” said Lydie Nzengou, the communications officer for Karim Meckassoua, a presidential candidate. “Why would the results for the presidential vote be more credible than those of the legislative vote?” ',
#   'print_section': 'A',
#   'print_page': '11',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'Central African Republic: Court Invalidates Legislative Election',
#    'kicker': 'World Briefing',
#    'content_kicker': None,
#    'print_headline': 'Africa; Central African Republic: Court Invalidates Legislative Election',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'persons',
#     'value': 'Dologuele, Anicet-Georges',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'glocations',
#     'value': 'Central African Republic',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'persons',
#     'value': 'Touadera, Faustin-Archange',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Elections', 'rank': 4, 'major': 'N'}],
#   'pub_date': '2016-01-26T01:49:11+0000',
#   'document_type': 'article',
#   'news_desk': 'Foreign',
#   'section_name': 'World',
#   'subsection_name': 'Africa',
#   'byline': {'original': 'By Margaux Benn',
#    'person': [{'firstname': 'Margaux',
#      'middlename': None,
#      'lastname': 'Benn',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Brief',
#   '_id': 'nyt://article/f564d3d5-bf08-5384-a3e2-18b28a426c2e',
#   'word_count': 128,
#   'uri': 'nyt://article/f564d3d5-bf08-5384-a3e2-18b28a426c2e'},
#  {'abstract': 'The Afghan election commission announced Monday that elections will be held Oct. 15, raising fears of a new political gridlock as the ruling coalition denounced the plan as illegitimate.',
#   'web_url': 'https://www.nytimes.com/video/world/asia/100000004151647/afghanistan-to-hold-elections.html',
#   'snippet': 'The Afghan election commission announced Monday that elections will be held Oct. 15, raising fears of a new political gridlock as the ruling coalition denounced the plan as illegitimate.',
#   'lead_paragraph': 'The Afghan election commission announced Monday that elections will be held Oct. 15, raising fears of a new political gridlock as the ruling coalition denounced the plan as illegitimate.',
#   'source': 'Reuters',
#   'multimedia': [{'rank': 0,
#     'subtype': 'watch308',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-watch308.jpg',
#     'height': 348,
#     'width': 312,
#     'legacy': {},
#     'subType': 'watch308',
#     'crop_name': 'watch308'},
#    {'rank': 0,
#     'subtype': 'watch268',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-watch268.jpg',
#     'height': 303,
#     'width': 272,
#     'legacy': {},
#     'subType': 'watch268',
#     'crop_name': 'watch268'},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-thumbWide.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoThumb.jpg',
#     'height': 50,
#     'width': 75,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoLarge.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-mediumThreeByTwo210.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-mediumThreeByTwo225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-mediumThreeByTwo440.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-mediumThreeByTwo252.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-mediumThreeByTwo378.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'facebookJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-facebookJumbo.jpg',
#     'height': 550,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'facebookJumbo',
#     'crop_name': 'facebookJumbo'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven1305',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoFifteenBySeven1305.jpg',
#     'height': 609,
#     'width': 1305,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven1305',
#     'crop_name': 'videoFifteenBySeven1305'},
#    {'rank': 0,
#     'subtype': 'miniMoth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-miniMoth.jpg',
#     'height': 70,
#     'width': 151,
#     'legacy': {},
#     'subType': 'miniMoth',
#     'crop_name': 'miniMoth'},
#    {'rank': 0,
#     'subtype': 'windowsTile336H',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-windowsTile336H.jpg',
#     'height': 336,
#     'width': 694,
#     'legacy': {},
#     'subType': 'windowsTile336H',
#     'crop_name': 'windowsTile336H'},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-articleLarge.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-articleLarge.jpg',
#      'xlargewidth': 600,
#      'xlargeheight': 338},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'blog480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-blog480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'blog480',
#     'crop_name': 'blog480'},
#    {'rank': 0,
#     'subtype': 'blog427',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-blog427.jpg',
#     'height': 240,
#     'width': 427,
#     'legacy': {},
#     'subType': 'blog427',
#     'crop_name': 'blog427'},
#    {'rank': 0,
#     'subtype': 'tmagArticle',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-tmagArticle.jpg',
#     'height': 333,
#     'width': 592,
#     'legacy': {},
#     'subType': 'tmagArticle',
#     'crop_name': 'tmagArticle'},
#    {'rank': 0,
#     'subtype': 'jumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-jumbo.jpg',
#     'height': 576,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-blog225.jpg',
#     'height': 127,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-master675.jpg',
#     'height': 380,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-master180.jpg',
#     'height': 101,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-master768.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-popup.jpg',
#     'height': 366,
#     'width': 650,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-blog533.jpg',
#     'height': 300,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-tmagSF.jpg',
#     'height': 204,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-slide.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-superJumbo.jpg',
#     'height': 1080,
#     'width': 1920,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-master1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-master495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-master315.jpg',
#     'height': 177,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-square320.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-filmstrip.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-square640.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-moth.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-mediumSquare149.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-articleInline.jpg',
#     'height': 107,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-hpSmall.jpg',
#     'height': 92,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-blogSmallInline.jpg',
#     'height': 85,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-mediumFlexible177.jpg',
#     'height': 100,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-sfSpan.jpg',
#     'height': 263,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-largeHorizontal375.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-hpLarge.jpg',
#     'height': 287,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-largeWidescreen573.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-largeWidescreen1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoSixteenByNine540.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoSixteenByNine495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoSixteenByNine390.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoSixteenByNine480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoSixteenByNine310.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoSixteenByNine225.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoSixteenByNine96.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
#     'crop_name': 'videoSixteenByNine96'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoSixteenByNine768.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoSixteenByNine768',
#     'crop_name': 'videoSixteenByNine768'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine150',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoSixteenByNine150.jpg',
#     'height': 84,
#     'width': 150,
#     'legacy': {},
#     'subType': 'videoSixteenByNine150',
#     'crop_name': 'videoSixteenByNine150'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-videoSixteenByNine1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'videoSixteenByNine1050',
#     'crop_name': 'videoSixteenByNine1050'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-thumbStandard.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'},
#    {'rank': 0,
#     'subtype': 'thumbLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-thumbLarge.jpg',
#     'height': 150,
#     'width': 150,
#     'legacy': {},
#     'subType': 'thumbLarge',
#     'crop_name': 'thumbLarge'},
#    {'rank': 0,
#     'subtype': 'smallSquare252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-smallSquare252.jpg',
#     'height': 252,
#     'width': 252,
#     'legacy': {},
#     'subType': 'smallSquare252',
#     'crop_name': 'smallSquare252'},
#    {'rank': 0,
#     'subtype': 'blogSmallThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-blogSmallThumb.jpg',
#     'height': 50,
#     'width': 50,
#     'legacy': {},
#     'subType': 'blogSmallThumb',
#     'crop_name': 'blogSmallThumb'},
#    {'rank': 0,
#     'subtype': 'smallSquare168',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/world/19AFGHAN-ELEX-VID/19AFGHAN-ELEX-VID-smallSquare168.jpg',
#     'height': 168,
#     'width': 168,
#     'legacy': {},
#     'subType': 'smallSquare168',
#     'crop_name': 'smallSquare168'}],
#   'headline': {'main': 'Afghanistan Sets Election Date',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Elections',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Independent Election Commission (Afghanistan)',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'Afghanistan', 'rank': 3, 'major': 'N'}],
#   'pub_date': '2016-01-18T16:48:15+0000',
#   'document_type': 'multimedia',
#   'news_desk': 'Foreign',
#   'section_name': 'World',
#   'subsection_name': 'Asia Pacific',
#   'byline': {'original': 'By REUTERS',
#    'person': [],
#    'organization': 'REUTERS'},
#   'type_of_material': 'Video',
#   '_id': 'nyt://video/4478b315-19ea-5a73-b274-d17f69c588dc',
#   'word_count': 0,
#   'uri': 'nyt://video/4478b315-19ea-5a73-b274-d17f69c588dc'},
#  {'abstract': 'Prime Minister Nikola Gruevski submitted his resignation on Friday as part of an agreement forged by Johannes Hahn.',
#   'web_url': 'https://www.nytimes.com/2016/01/19/world/europe/macedonia-elections-scheduled-but-opposition-threatens-boycott.html',
#   'snippet': 'Prime Minister Nikola Gruevski submitted his resignation on Friday as part of an agreement forged by Johannes Hahn.',
#   'lead_paragraph': 'Macedonia’s governing coalition is moving forward with a European Union-brokered plan for elections in April even though the opposition has threatened to boycott the vote, which would be run by a caretaker government. Johannes Hahn, the European Union commissioner who took the leading role in the negotiations for ending the political crisis in the Balkan country, said he would have preferred a consensual solution regarding the date of the elections. Prime Minister Nikola Gruevski submitted his resignation on Friday as part of an agreement forged by Mr. Hahn. That agreement sought to end a political crisis that erupted last February over a wiretapping scandal. ',
#   'print_section': 'A',
#   'print_page': '6',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'Macedonia: Elections Scheduled, but Opposition Threatens Boycott',
#    'kicker': 'World Briefing',
#    'content_kicker': None,
#    'print_headline': 'Europe; Macedonia: Elections Scheduled, but Opposition Threatens Boycott',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'glocations',
#     'value': 'Macedonia',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Elections', 'rank': 2, 'major': 'N'},
#    {'name': 'subject', 'value': 'Boycotts', 'rank': 3, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'European Union',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'persons',
#     'value': 'Gruevski, Nikola (1970- )',
#     'rank': 5,
#     'major': 'N'}],
#   'pub_date': '2016-01-19T03:21:17+0000',
#   'document_type': 'article',
#   'news_desk': 'Foreign',
#   'section_name': 'World',
#   'subsection_name': 'Europe',
#   'byline': {'original': 'By Aleksandar Dimishkovski',
#    'person': [{'firstname': 'Aleksandar',
#      'middlename': None,
#      'lastname': 'Dimishkovski',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Brief',
#   '_id': 'nyt://article/467ed093-8d7b-5318-b6df-107e64687cb7',
#   'word_count': 104,
#   'uri': 'nyt://article/467ed093-8d7b-5318-b6df-107e64687cb7'},
#  {'abstract': 'Presidential candidates and their supporters took to the streets of Taipei, Taiwan’s capital, before election day on Saturday.',
#   'web_url': 'https://www.nytimes.com/video/world/asia/100000004147556/taiwan-on-the-eve-of-elections.html',
#   'snippet': 'Presidential candidates and their supporters took to the streets of Taipei, Taiwan’s capital, before election day on Saturday.',
#   'lead_paragraph': 'Presidential candidates and their supporters took to the streets of Taipei, Taiwan’s capital, before election day on Saturday.',
#   'source': 'Reuters',
#   'multimedia': [{'rank': 0,
#     'subtype': 'watch308',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-watch308.jpg',
#     'height': 348,
#     'width': 312,
#     'legacy': {},
#     'subType': 'watch308',
#     'crop_name': 'watch308'},
#    {'rank': 0,
#     'subtype': 'watch268',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-watch268.jpg',
#     'height': 304,
#     'width': 272,
#     'legacy': {},
#     'subType': 'watch268',
#     'crop_name': 'watch268'},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-thumbWide.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoThumb.jpg',
#     'height': 50,
#     'width': 75,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoLarge.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-mediumThreeByTwo210.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-mediumThreeByTwo225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-mediumThreeByTwo440.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-mediumThreeByTwo252.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-mediumThreeByTwo378.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'facebookJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-facebookJumbo.jpg',
#     'height': 550,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'facebookJumbo',
#     'crop_name': 'facebookJumbo'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven1305',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoFifteenBySeven1305.jpg',
#     'height': 609,
#     'width': 1305,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven1305',
#     'crop_name': 'videoFifteenBySeven1305'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven2610',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoFifteenBySeven2610.jpg',
#     'height': 1218,
#     'width': 2610,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven2610',
#     'crop_name': 'videoFifteenBySeven2610'},
#    {'rank': 0,
#     'subtype': 'miniMoth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-miniMoth.jpg',
#     'height': 70,
#     'width': 151,
#     'legacy': {},
#     'subType': 'miniMoth',
#     'crop_name': 'miniMoth'},
#    {'rank': 0,
#     'subtype': 'windowsTile336H',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-windowsTile336H.jpg',
#     'height': 336,
#     'width': 694,
#     'legacy': {},
#     'subType': 'windowsTile336H',
#     'crop_name': 'windowsTile336H'},
#    {'rank': 0,
#     'subtype': 'verticalTwoByThree735',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-verticalTwoByThree735.jpg',
#     'height': 1103,
#     'width': 735,
#     'legacy': {},
#     'subType': 'verticalTwoByThree735',
#     'crop_name': 'verticalTwoByThree735'},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-articleLarge.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-articleLarge.jpg',
#      'xlargewidth': 600,
#      'xlargeheight': 338},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'blog480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-blog480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'blog480',
#     'crop_name': 'blog480'},
#    {'rank': 0,
#     'subtype': 'blog427',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-blog427.jpg',
#     'height': 240,
#     'width': 427,
#     'legacy': {},
#     'subType': 'blog427',
#     'crop_name': 'blog427'},
#    {'rank': 0,
#     'subtype': 'tmagArticle',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-tmagArticle.jpg',
#     'height': 333,
#     'width': 592,
#     'legacy': {},
#     'subType': 'tmagArticle',
#     'crop_name': 'tmagArticle'},
#    {'rank': 0,
#     'subtype': 'jumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-jumbo.jpg',
#     'height': 577,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-blog225.jpg',
#     'height': 127,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-master675.jpg',
#     'height': 380,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-master180.jpg',
#     'height': 101,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-master768.jpg',
#     'height': 433,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-popup.jpg',
#     'height': 366,
#     'width': 650,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-blog533.jpg',
#     'height': 300,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-tmagSF.jpg',
#     'height': 204,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-slide.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-superJumbo.jpg',
#     'height': 1153,
#     'width': 2048,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-master1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-master495.jpg',
#     'height': 279,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-master315.jpg',
#     'height': 177,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-square320.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-filmstrip.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-square640.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-moth.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-mediumSquare149.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-articleInline.jpg',
#     'height': 107,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-hpSmall.jpg',
#     'height': 92,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-blogSmallInline.jpg',
#     'height': 85,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-mediumFlexible177.jpg',
#     'height': 100,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-sfSpan.jpg',
#     'height': 264,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-largeHorizontal375.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-hpLarge.jpg',
#     'height': 288,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-largeWidescreen573.jpg',
#     'height': 323,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-largeWidescreen1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoSixteenByNine540.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoSixteenByNine495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoSixteenByNine390.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoSixteenByNine480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoSixteenByNine310.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoSixteenByNine225.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoSixteenByNine96.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
#     'crop_name': 'videoSixteenByNine96'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoSixteenByNine768.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoSixteenByNine768',
#     'crop_name': 'videoSixteenByNine768'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine150',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoSixteenByNine150.jpg',
#     'height': 84,
#     'width': 150,
#     'legacy': {},
#     'subType': 'videoSixteenByNine150',
#     'crop_name': 'videoSixteenByNine150'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-videoSixteenByNine1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'videoSixteenByNine1050',
#     'crop_name': 'videoSixteenByNine1050'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/16/world/16TAIWAN-still/16TAIWAN-still-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
# ...
#     'subType': 'tmagArticle',
#     'crop_name': 'tmagArticle'},
#    {'rank': 0,
#     'subtype': 'jumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-jumbo-v2.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-blog225-v2.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-master675-v2.jpg',
#     'height': 450,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-master180-v2.jpg',
#     'height': 120,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-master768-v2.jpg',
#     'height': 512,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-popup-v2.jpg',
#     'height': 433,
#     'width': 650,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-blog533-v2.jpg',
#     'height': 355,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-tmagSF-v2.jpg',
#     'height': 241,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-slide-v2.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-superJumbo-v2.jpg',
#     'height': 1365,
#     'width': 2048,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-master1050-v2.jpg',
#     'height': 700,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-master495-v2.jpg',
#     'height': 330,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-master315-v2.jpg',
#     'height': 210,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-square320-v3.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-filmstrip-v3.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-square640-v3.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-moth-v3.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-mediumSquare149-v3.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-articleInline-v2.jpg',
#     'height': 127,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-hpSmall-v2.jpg',
#     'height': 109,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-blogSmallInline-v2.jpg',
#     'height': 101,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-mediumFlexible177-v2.jpg',
#     'height': 118,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-sfSpan-v2.jpg',
#     'height': 263,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-largeHorizontal375-v2.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-hpLarge-v2.jpg',
#     'height': 287,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-largeWidescreen573-v2.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-largeWidescreen1050-v2.jpg',
#     'height': 590,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-videoSmall-v2.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-videoHpMedium-v2.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-videoSixteenByNine600-v2.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-videoSixteenByNine540-v2.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-videoSixteenByNine495-v2.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-videoSixteenByNine390-v2.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-videoSixteenByNine480-v2.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-videoSixteenByNine310-v2.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-videoSixteenByNine225-v2.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-videoSixteenByNine96-v2.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
#     'crop_name': 'videoSixteenByNine96'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-videoSixteenByNine768-v2.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoSixteenByNine768',
#     'crop_name': 'videoSixteenByNine768'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine150',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-videoSixteenByNine150-v2.jpg',
#     'height': 84,
#     'width': 150,
#     'legacy': {},
#     'subType': 'videoSixteenByNine150',
#     'crop_name': 'videoSixteenByNine150'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-videoSixteenByNine1050-v2.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'videoSixteenByNine1050',
#     'crop_name': 'videoSixteenByNine1050'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-thumbStandard-v3.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-thumbStandard-v3.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'},
#    {'rank': 0,
#     'subtype': 'thumbLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-thumbLarge-v3.jpg',
#     'height': 150,
#     'width': 150,
#     'legacy': {},
#     'subType': 'thumbLarge',
#     'crop_name': 'thumbLarge'},
#    {'rank': 0,
#     'subtype': 'smallSquare252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-smallSquare252-v3.jpg',
#     'height': 252,
#     'width': 252,
#     'legacy': {},
#     'subType': 'smallSquare252',
#     'crop_name': 'smallSquare252'},
#    {'rank': 0,
#     'subtype': 'blogSmallThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-blogSmallThumb-v3.jpg',
#     'height': 50,
#     'width': 50,
#     'legacy': {},
#     'subType': 'blogSmallThumb',
#     'crop_name': 'blogSmallThumb'},
#    {'rank': 0,
#     'subtype': 'smallSquare168',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/19/us/00kentucky-web1/00kentucky-web1-smallSquare168-v3.jpg',
#     'height': 168,
#     'width': 168,
#     'legacy': {},
#     'subType': 'smallSquare168',
#     'crop_name': 'smallSquare168'}],
#   'headline': {'main': 'Fading Presidential Hopes Complicate Rand Paul’s Senate Re-Election Bid',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Higher Hopes Fading, Paul Doesn&#8217;t Heed Call of Home ',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'persons',
#     'value': 'Paul, Rand',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'Kentucky', 'rank': 3, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Presidential Election of 2016',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Elections, Senate', 'rank': 5, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Republican Party',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Polls and Public Opinion',
#     'rank': 7,
#     'major': 'N'}],
#   'pub_date': '2016-01-20T14:43:33+0000',
#   'document_type': 'article',
#   'news_desk': 'National',
#   'section_name': 'U.S.',
#   'subsection_name': 'Politics',
#   'byline': {'original': 'By Sheryl Gay Stolberg',
#    'person': [{'firstname': 'Sheryl',
#      'middlename': 'Gay',
#      'lastname': 'Stolberg',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/8d15b428-253e-5543-8325-5c82601017fa',
#   'word_count': 1235,
#   'uri': 'nyt://article/8d15b428-253e-5543-8325-5c82601017fa'}]

# %%
# Retrieve articles

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param

# %%
# Print article snippets
