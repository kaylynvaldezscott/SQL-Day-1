# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %%
# Store filepaths into variable
state_avg_csv = Path("Resources/state_avg.csv")
state_totals_csv = Path("Resources/state_totals.csv")

# %%
# Read in files.
state_avg_df = pd.read_csv(state_avg_csv)
state_totals_df = pd.read_csv(state_totals_csv)

# %%
# Display the state averages.
state_avg_df.head(2)
# Out:
#    Year    State  Average Median Age by County  \
# 0  2016  Alabama                     40.250746
# 1  2016   Alaska                     36.624138
#
#    Average Household Income by County  Average Per Capita Income by County
# 0                        38834.925373                         21232.746269
# 1                        64801.655172                         31052.103448

# %%
# Display the state totals.
state_totals_df.head(2)
# Out:
#    Year    State  Total Population  Total Employed Civilians  \
# 0  2016  Alabama           4841164                 2042025.0
# 1  2016   Alaska            736855                  353954.0
#
#    Total Unemployed Civilians  Total People in the Military  \
# 0                    184479.0                       12150.0
# 1                     30139.0                       16382.0
#
#    Total Population in Poverty
# 0                     868666.0
# 1                      72826.0

# %%
# Merge the two DataFrames together based on the Year and State they share
df=state_avg_df.merge(state_totals_df,  on=['Year','State'])
df.head(2)
# Out:
#    Year    State  Average Median Age by County  \
# 0  2016  Alabama                     40.250746
# 1  2016   Alaska                     36.624138
#
#    Average Household Income by County  Average Per Capita Income by County  \
# 0                        38834.925373                         21232.746269
# 1                        64801.655172                         31052.103448
#
#    Total Population  Total Employed Civilians  Total Unemployed Civilians  \
# 0           4841164                 2042025.0                    184479.0
# 1            736855                  353954.0                     30139.0
#
#    Total People in the Military  Total Population in Poverty
# 0                       12150.0                     868666.0
# 1                       16382.0                      72826.0

# %%
# Create a DataFrame that filters the data on only 2019
df1=df[df.Year==2019]
df1.head()
# Out:
#      Year       State  Average Median Age by County  \
# 156  2019     Alabama                     40.801493
# 157  2019      Alaska                     37.279310
# 158  2019     Arizona                     40.626667
# 159  2019    Arkansas                     41.610667
# 160  2019  California                     39.889655
#
#      Average Household Income by County  Average Per Capita Income by County  \
# 156                        43574.850746                         24049.149254
# 157                        67789.344828                         33072.896552
# 158                        48989.933333                         24500.266667
# 159                        42236.706667                         23285.040000
# 160                        67713.603448                         33798.620690
#
#      Total Population  Total Employed Civilians  Total Unemployed Civilians  \
# 156           4876250                 2097384.0                    132095.0
# 157            737068                  347774.0                     26808.0
# 158           7050299                 3130658.0                    195905.0
# 159           2999370                 1303490.0                     70481.0
# 160          39283497                18591241.0                   1199233.0
#
#      Total People in the Military  Total Population in Poverty
# 156                       13306.0                     795989.0
# 157                       17756.0                      76933.0
# 158                       19592.0                    1043764.0
# 159                        4751.0                     496260.0
# 160                      131073.0                    5149742.0

# %%
# Add a new column that calculates the Poverty Rate
df['Poverty Rate %']=df['Total Population in Poverty']/df['Total Population']*100
df.head(2)
# Out:
#    Year    State  Average Median Age by County  \
# 0  2016  Alabama                     40.250746
# 1  2016   Alaska                     36.624138
#
#    Average Household Income by County  Average Per Capita Income by County  \
# 0                        38834.925373                         21232.746269
# 1                        64801.655172                         31052.103448
#
#    Total Population  Total Employed Civilians  Total Unemployed Civilians  \
# 0           4841164                 2042025.0                    184479.0
# 1            736855                  353954.0                     30139.0
#
#    Total People in the Military  Total Population in Poverty  Poverty Rate %
# 0                       12150.0                     868666.0       17.943329
# 1                       16382.0                      72826.0        9.883356

# %%
df.sort_values(['Poverty Rate %','Average Per Capita Income by County'],ascending=False)
# Out:
#      Year          State  Average Median Age by County  \
# 39   2016    Puerto Rico                     39.189744
# 91   2017    Puerto Rico                     39.919231
# 143  2018    Puerto Rico                     40.847436
# 195  2019    Puerto Rico                     41.656410
# 24   2016    Mississippi                     38.031707
# ..    ...            ...                           ...
# 176  2019       Maryland                     41.066667
# 29   2016  New Hampshire                     43.960000
# 81   2017  New Hampshire                     44.200000
# 133  2018  New Hampshire                     44.310000
# 185  2019  New Hampshire                     44.540000
#
#      Average Household Income by County  Average Per Capita Income by County  \
# 39                         18200.730769                          9870.653846
# 91                         18412.948718                         10244.961538
# 143                        18923.628205                         10632.487179
# 195                        19300.025641                         11067.884615
# 24                         35626.414634                         19353.097561
# ..                                  ...                                  ...
# 176                        77541.625000                         38085.416667
# 29                         62390.900000                         32780.700000
# 81                         64901.900000                         34212.900000
# 133                        67438.200000                         35540.200000
# 185                        69308.200000                         36819.600000
#
#      Total Population  Total Employed Civilians  Total Unemployed Civilians  \
# 39            3529385                 1055106.0                    226880.0
# 91            3468963                 1040136.0                    220597.0
# 143           3386941                 1028500.0                    209950.0
# 195           3318447                 1028513.0                    196934.0
# 24            2989192                 1212650.0                    128840.0
# ..                ...                       ...                         ...
# 176           6018848                 3073886.0                    164396.0
# 29            1327503                  706801.0                     37727.0
# 81            1331848                  713424.0                     33566.0
# 133           1343622                  724017.0                     30392.0
# 185           1348124                  729701.0                     27430.0
#
#      Total People in the Military  Total Population in Poverty  Poverty Rate %
# 39                         1204.0                    1577075.0       44.684131
# 91                         1487.0                    1543220.0       44.486494
# 143                        1583.0                    1495160.0       44.144849
# 195                        1845.0                    1449091.0       43.667746
# 24                        10307.0                     645553.0       21.596237
# ..                            ...                          ...             ...
# 176                       30952.0                     539991.0        8.971667
# 29                         1675.0                     109690.0        8.262882
# 81                         1789.0                     104470.0        7.843988
# 133                        1830.0                     102352.0        7.617619
# 185                        1950.0                      98682.0        7.319950
#
# [208 rows x 11 columns]

# %%
# Sort the data by Poverty Rate and Average Per Capita Income by County, Highest to Lowest
df2=df.sort_values(['Poverty Rate %','Average Per Capita Income by County'],ascending=False).reset_index(drop=True)
df2.head()
# Reset Index
# Out:
#    Year        State  Average Median Age by County  \
# 0  2016  Puerto Rico                     39.189744
# 1  2017  Puerto Rico                     39.919231
# 2  2018  Puerto Rico                     40.847436
# 3  2019  Puerto Rico                     41.656410
# 4  2016  Mississippi                     38.031707
#
#    Average Household Income by County  Average Per Capita Income by County  \
# 0                        18200.730769                          9870.653846
# 1                        18412.948718                         10244.961538
# 2                        18923.628205                         10632.487179
# 3                        19300.025641                         11067.884615
# 4                        35626.414634                         19353.097561
#
#    Total Population  Total Employed Civilians  Total Unemployed Civilians  \
# 0           3529385                 1055106.0                    226880.0
# 1           3468963                 1040136.0                    220597.0
# 2           3386941                 1028500.0                    209950.0
# 3           3318447                 1028513.0                    196934.0
# 4           2989192                 1212650.0                    128840.0
#
#    Total People in the Military  Total Population in Poverty  Poverty Rate %
# 0                        1204.0                    1577075.0       44.684131
# 1                        1487.0                    1543220.0       44.486494
# 2                        1583.0                    1495160.0       44.144849
# 3                        1845.0                    1449091.0       43.667746
# 4                       10307.0                     645553.0       21.596237

# %%
# Print out the data for the state or territory with the highest poverty rate
df2.loc[0,:]
# Out:
# Year                                           2016
# State                                   Puerto Rico
# Average Median Age by County              39.189744
# Average Household Income by County     18200.730769
# Average Per Capita Income by County     9870.653846
# Total Population                            3529385
# Total Employed Civilians                  1055106.0
# Total Unemployed Civilians                 226880.0
# Total People in the Military                 1204.0
# Total Population in Poverty               1577075.0
# Poverty Rate %                            44.684131
# Name: 0, dtype: object

# %%
len(df2)-1
# Out:
# 207

# %%
# Bonus: Print out the data for the state or territory with the lowest poverty rate with one line of code
df2.loc[len(df2)-1,:]
# Out:
# Year                                            2019
# State                                  New Hampshire
# Average Median Age by County                   44.54
# Average Household Income by County           69308.2
# Average Per Capita Income by County          36819.6
# Total Population                             1348124
# Total Employed Civilians                    729701.0
# Total Unemployed Civilians                   27430.0
# Total People in the Military                  1950.0
# Total Population in Poverty                  98682.0
# Poverty Rate %                               7.31995
# Name: 207, dtype: object

# %%
df2.tail(1)
# Out:
#      Year          State  Average Median Age by County  \
# 207  2019  New Hampshire                         44.54
#
#      Average Household Income by County  Average Per Capita Income by County  \
# 207                             69308.2                              36819.6
#
#      Total Population  Total Employed Civilians  Total Unemployed Civilians  \
# 207           1348124                  729701.0                     27430.0
#
#      Total People in the Military  Total Population in Poverty  Poverty Rate %
# 207                        1950.0                      98682.0         7.31995
