# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
car_data = pd.read_csv('../Resources/mpg.csv')
car_data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
#car_data[~car_data['horsepower'].apply(lambda x: str(x).isnumeric())]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0          ?    2046          19.0
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 336  23.6          4         140.0          ?    2905          14.3
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
#
#      model year  origin              car name
# 32           71       1            ford pinto
# 126          74       1         ford maverick
# 330          80       2  renault lecar deluxe
# 336          80       1    ford mustang cobra
# 354          81       2           renault 18i
# 374          82       1        amc concord dl

# %%
car_data['horsepower'].apply(lambda x: str(x).isnumeric())
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 393    True
# 394    True
# 395    True
# 396    True
# 397    True
# Name: horsepower, Length: 398, dtype: bool

# %%
car_data=car_data[~(car_data.horsepower=='?')]

# %%
# Remove the rows with missing values in horsepower
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
car_data=car_data.set_index('car name')

# %%
# Set the 'car name' as our index

# Remove the 'origin' column
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# car name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
#
#                            acceleration  model year
# car name
# chevrolet chevelle malibu          12.0          70
# buick skylark 320                  11.5          70
# plymouth satellite                 11.0          70
# amc rebel sst                      12.0          70
# ford torino                        10.5          70

# %%
del car_data['origin']

# %%
car_data.head()
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# car name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
#
#                            acceleration  model year
# car name
# chevrolet chevelle malibu          12.0          70
# buick skylark 320                  11.5          70
# plymouth satellite                 11.0          70
# amc rebel sst                      12.0          70
# ford torino                        10.5          70

# %%
# Convert the "horsepower.astype('float64')" column to numeric so the data can be used
car_data.horsepower=car_data.horsepower.astype('float64')

# %%
# Create a scatter plot which compares MPG to horsepower
car_data.plot(kind='scatter' ,x='horsepower' ,y='mpg' )
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Axes: xlabel='horsepower', ylabel='mpg'>
